# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
df_train = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/train.csv')
df_test = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/test.csv')
df_greeks=pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/greeks.csv')
df_submit = pd.read_csv('/kaggle/input/icr-identify-age-related-conditions/sample_submission.csv')
df_train.head()

# %%
df_test.head()

# %%
df_submit

# %%
#check class counts
target_column = 'Class'
target_count = df_train['Class'].value_counts()
print(target_count)

# %%
import matplotlib.pyplot as plt
target_count.plot(kind='bar')
plt.title('Class Distribution')
plt.ylabel('Count')
plt.xlabel('Class')
plt.show()

# %%
#check missing values
missing_value = df_train.isnull().sum()
total_missing_value = df_train.isnull().sum().sum()
column_missing_value = missing_value[missing_value>0]
print(column_missing_value)
print(f'total missing value {total_missing_value}')

# %%
missing_value_by_class = df_train.groupby(target_column).apply(lambda x: x.isnull().sum()[x.isnull().sum()>0])

print(missing_value_by_class )

# %%
#handle categorical column for both train and test dataset
df_train['EJ'] = df_train['EJ'].replace({'A':0, 'B':1})
df_test['EJ'] = df_test['EJ'].replace({'A':0, 'B':1})
print(df_train['EJ'])

# %%
train = df_train.drop(df_train.columns[0], axis=1)
train

# %%
test1=df_test.drop('Id',axis=1)
test1

# %%
y = train['Class']
y = y.values
X = train.drop(columns='Class')
X.shape

# %%
X=X.fillna(np.nan)
test1=test1.fillna(np.nan)

# %%
y.shape

# %% [markdown]
# #Apply median for missing values

# %%
from sklearn.impute import SimpleImputer

imputer=SimpleImputer(missing_values=np.nan, strategy='median')

X_imputed = imputer.fit_transform(X)
test1_imputed = imputer.transform(test1)

# %%
X=np.array(X_imputed)
test1=np.array(test1_imputed)
test1

# %%
test1_imputed.shape

# %%
#Split the train dataset into train & test datasets in a ration 75:25
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state=42, shuffle = True, stratify = y)

print(X_train.shape)
print(X_test.shape)

# %%
#Classifers

# %% [markdown]
# # KNN

# %%
from scipy.spatial.distance import hamming
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
#GridSearch to get best tuned parameters
tuned_parameters = [{'n_neighbors': [3,4,5,6,7,8,9,10],
                      'metric':['hamming', 'manhattan', 'euclidean']}]

knn_model = GridSearchCV(estimator=KNeighborsClassifier(weights='uniform'),
                         param_grid=tuned_parameters,
                         refit=True,
                         cv=4,
                         n_jobs=None,
                         scoring='f1')

knn_model.fit(X_train, y_train)

print('Best F1 score: %.2f%%' % (knn_model.best_score_*100))
print('Best Params:', knn_model.best_params_)

# %%
#classifier model run
knn_model = KNeighborsClassifier(weights = 'uniform',n_neighbors=5, metric='euclidean')
knn_model.fit(X_train, y_train)
y_pred = knn_model.predict(X_test)
num_correct_predictions = (y_pred == y_test).sum()
accuracy = (num_correct_predictions / y_test.shape[0]) * 100
print('Accuracy score: %.2f%%' % accuracy)

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %%
#Evaluation metrics

from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = knn_model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, knn_model.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[122   6]
# [ 18   9]]
#
# Accuracy: 0.8451612903225807
#
# Precision: 0.6
#
# Recall: 0.3333333333333333
#
# F1-Score: 0.42857142857142855
#
# ROC-AUC: 0.685619212962963
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91       128
#            1       0.60      0.33      0.43        27
#
#     accuracy                           0.85       155
#    macro avg       0.74      0.64      0.67       155
# weighted avg       0.82      0.85      0.83       155

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=10000, solver='liblinear',random_state=42, penalty="l1")
log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print('Accuracy score: %.2f%%' % accuracy)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# %%
#evaluation metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = log_reg.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, log_reg.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[124   4]
#  [ 12  15]]
#
# Accuracy: 0.896774193548387
#
# Precision: 0.7894736842105263
#
# Recall: 0.5555555555555556
#
# F1-Score: 0.6521739130434783
#
# ROC-AUC: 0.8718171296296295
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       128
#            1       0.79      0.56      0.65        27
#
#     accuracy                           0.90       155
#    macro avg       0.85      0.76      0.80       155
# weighted avg       0.89      0.90      0.89       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %% [markdown]
# # Catboost

# %%
from catboost import CatBoostClassifier
from sklearn.utils.class_weight import compute_class_weight

# %%
#class weight assigned 
classes = np.unique(y_train)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weights = dict(zip(classes, weights))

#cat boost classifier
catboost = CatBoostClassifier(class_weights=class_weights, random_state=42)


tuned_parameters = {'learning_rate': [0.01, 0.1],
                    'depth': [3,6,9],
                    'iterations': [100,200,300]}


grid_search = GridSearchCV(estimator=catboost, param_grid= tuned_parameters, cv=5, n_jobs=None, scoring='f1')
grid_search.fit(X_train, y_train)


print("Best Parameters: ", grid_search.best_params_)
print("Best F1-score: {:.2f}%".format(grid_search.best_score_ * 100))


best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy: {:.2f}%".format(accuracy * 100))

# %%
from sklearn.utils.class_weight import compute_class_weight
 
classes = np.unique(y_train)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weights = dict(zip(classes, weights))

# %%
#classifer with tuned parameters
from catboost import CatBoostClassifier

catboost_model = CatBoostClassifier(depth=6,iterations=100, learning_rate=0.1, class_weights=class_weights, random_state=42)
catboost_model.fit(X_train, y_train)

y_pred = catboost_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy: {:.2f}%".format(accuracy * 100))

# %%
#Evaluation metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = catboost_model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, catboost_model.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[120   8]
#  [  6  21]]
#
# Accuracy: 0.9096774193548387
#
# Precision: 0.7241379310344828
#
# Recall: 0.7777777777777778
#
# F1-Score: 0.75
#
# ROC-AUC: 0.9635416666666666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94       128
#            1       0.72      0.78      0.75        27
#
#     accuracy                           0.91       155
#    macro avg       0.84      0.86      0.85       155
# weighted avg       0.91      0.91      0.91       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %% [markdown]
# log loss 3.255555789984775

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.utils.class_weight import compute_sample_weight

# %%
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)

tuned_parameters = [{'max_depth': [ 3,4,5,6],
                     'n_estimators': [200, 300,400,500],
                     'learning_rate': [0.01, 0.1, 0.001]}]

gs = GridSearchCV(estimator=GradientBoostingClassifier(random_state=121),
                  param_grid=tuned_parameters,
                  refit=True,
                  cv=5,
                  n_jobs=None,
                  scoring='f1')

gs.fit(X_train, y_train, sample_weight=sample_weights)

print('Best F1 score: %.2f%%' % (gs.best_score_*100))
print('Best Params:', gs.best_params_)

# %%
#classifier with tuned parameters
gs_model = GradientBoostingClassifier(random_state=121, learning_rate=0.01, max_depth=3, n_estimators=400)
gs_model.fit(X_train, y_train, sample_weights)
y_pred_test = gs_model.predict(X_test)
f1_test = f1_score(y_test, y_pred_test)

print("F1 score on Test Set: %.2f%%" % (f1_test*100))

# %%
#Evaluation Metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = gs_model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, gs_model.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[121   7]
#  [  6  21]]
#
# Accuracy: 0.9161290322580645
#
# Precision: 0.75
#
# Recall: 0.7777777777777778
#
# F1-Score: 0.7636363636363638
#
# ROC-AUC: 0.9551504629629629
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       128
#            1       0.75      0.78      0.76        27
#
#     accuracy                           0.92       155
#    macro avg       0.85      0.86      0.86       155
# weighted avg       0.92      0.92      0.92       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %% [markdown]
# 3.0230160907001484

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from sklearn.utils.class_weight import compute_sample_weight
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)

# %%
#classifier 
xgb_model = xgb.XGBClassifier(
    objective='binary:logistic', 
    eval_metric='logloss',       
    use_label_encoder=False      
)

xgb_model.fit(X_train, y_train, sample_weights)
y_pred = xgb_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))

# %%
#Evaluation metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = xgb_model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, xgb_model.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[123   5]
#  [  5  22]]
#
# Accuracy: 0.9354838709677419
#
# Precision: 0.8148148148148148
#
# Recall: 0.8148148148148148
#
# F1-Score: 0.8148148148148148
#
# ROC-AUC: 0.9635416666666666
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       128
#            1       0.81      0.81      0.81        27
#
#     accuracy                           0.94       155
#    macro avg       0.89      0.89      0.89       155
# weighted avg       0.94      0.94      0.94       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %% [markdown]
# 2.325396992846268

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils.class_weight import compute_sample_weight

sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)

# %%
dt = DecisionTreeClassifier()

tuned_parameters = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3,7,8,9],
    'min_samples_split': [2, 3,5,8, 10],
    'min_samples_leaf': [1, 2, 4,5,7,8,10]
}

grid_search = GridSearchCV(estimator= dt, param_grid= tuned_parameters, cv=5, n_jobs=None, scoring='accuracy')
grid_search.fit(X_train, y_train, sample_weight=sample_weights)

print("Best Parameters: ", grid_search.best_params_)
print("Best Accuracy: {:.2f}%".format(grid_search.best_score_ * 100))

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

print("Classification Report:")
print(classification_report(y_test, y_pred))

# %%
tree = DecisionTreeClassifier(max_depth=8,min_samples_leaf=1,min_samples_split= 3, criterion='entropy', random_state=42)
tree.fit(X_train, y_train, sample_weight=sample_weights)

y_pred = tree.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))

# %%
#Evaluation metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = tree.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, tree.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[117  11]
#  [  7  20]]
#
# Accuracy: 0.8838709677419355
#
# Precision: 0.6451612903225806
#
# Recall: 0.7407407407407407
#
# F1-Score: 0.689655172413793
#
# ROC-AUC: 0.8274016203703703
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       128
#            1       0.65      0.74      0.69        27
#
#     accuracy                           0.88       155
#    macro avg       0.79      0.83      0.81       155
# weighted avg       0.89      0.88      0.89       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %% [markdown]
# 4.185714587123282

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(random_state=42)

tuned_parameters = {'n_estimators': [50, 100,200, 300],
                    'max_depth': [3,5,10, 20],
                    'min_samples_split': [5, 10, 15, 20],
                    'min_samples_leaf': [1, 2, 4, 5, 8]}


grid_search = GridSearchCV(estimator=rf_model, param_grid= tuned_parameters, cv=5, n_jobs=None, scoring='accuracy')


grid_search.fit(X_train, y_train)


print("Best Parameters: ", grid_search.best_params_)
print("Best Accuracy: {:.2f}%".format(grid_search.best_score_ * 100))

best_rf_model = grid_search.best_estimator_
y_pred = best_rf_model.predict(X_test)

# %%
rf_model = RandomForestClassifier(class_weight ='balanced',max_depth=10, min_samples_leaf= 1,min_samples_split= 5, n_estimators= 200, random_state=123)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))

print("Classification Report:")
print(classification_report(y_test, y_pred))

# %%
#Evaluation Metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = rf_model.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, rf_model.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[125   3]
#  [ 11  16]]
#
# Accuracy: 0.9096774193548387
#
# Precision: 0.8421052631578947
#
# Recall: 0.5925925925925926
#
# F1-Score: 0.6956521739130435
#
# ROC-AUC: 0.9641203703703703
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       128
#            1       0.84      0.59      0.70        27
#
#     accuracy                           0.91       155
#    macro avg       0.88      0.78      0.82       155
# weighted avg       0.91      0.91      0.90       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %% [markdown]
# 3.255555789984775

# %% [markdown]
# # Bagging

# %%
from sklearn.ensemble import BaggingClassifier

# %%
#bagging with gradident boost
bagging_gs = BaggingClassifier(gs_model,
                               n_estimators=100,       
                               max_samples=0.6,       
                               max_features=0.5,       
                               bootstrap=False,         
                               random_state=42)

bagging_gs.fit(X_train, y_train)
y_pred = bagging_gs.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
print("Classification Report:")
print(classification_report(y_test, y_pred))

# %%
#bagging with catboost
bagging_cat = BaggingClassifier(catboost_model,
                                n_estimators=100,       
                                max_samples=0.8,       
                                max_features=0.5,       
                                bootstrap=False,         
                                random_state=42)


bagging_cat.fit(X_train, y_train)
y_pred = bagging_cat.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
print("Classification Report:")
print(classification_report(y_test, y_pred))

# %%
#Bagging with xgboost
bagging_xgb = BaggingClassifier(xgb_model,
                                n_estimators=100,       
                                max_samples=0.8,       
                                max_features=0.5,       
                                bootstrap=False,         
                                random_state=42)


bagging_xgb.fit(X_train, y_train)
y_pred = bagging_xgb.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))
print("Classification Report:")
print(classification_report(y_test, y_pred))

# %%
#evaluation metrics for best one (catboost)
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = bagging_cat.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, bagging_cat.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[124   4]
#  [  6  21]]
#
# Accuracy: 0.9354838709677419
#
# Precision: 0.84
#
# Recall: 0.7777777777777778
#
# F1-Score: 0.8076923076923077
#
# ROC-AUC: 0.9629629629629629
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       128
#            1       0.84      0.78      0.81        27
#
#     accuracy                           0.94       155
#    macro avg       0.90      0.87      0.88       155
# weighted avg       0.93      0.94      0.93       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %% [markdown]
# 2.325396992846268

# %% [markdown]
# # Majority Voting

# %%
from sklearn.ensemble import VotingClassifier

# %%
#base models

# clf1 = tree
clf2 = rf_model
clf3 = catboost_model
clf4 = xgb_model
clf5 = gs_model
clf6 = bagging_gs
clf7 = bagging_cat
clf8 = bagging_xgb

voting_classifier = VotingClassifier(
    estimators=[('rf', clf2), ('cat', clf3), ('xgb', clf4), ('gs', clf5),('bg_gs', clf6), ('bg_cat', clf7), ('bg_xgb', clf8)],
    voting='soft' 
)

voting_classifier.fit(X_train, y_train)
y_pred = voting_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {:.2f}%".format(accuracy * 100))

print("Classification Report:")
print(classification_report(y_test, y_pred))

# %%
#Evaluation Metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = voting_classifier.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, voting_classifier.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)

# %% [markdown]
# Confusion Matrix:
# [[124   4]
#  [  6  21]]
#
# Accuracy: 0.9354838709677419
# Precision: 0.84
# Recall: 0.7777777777777778
# F1-Score: 0.8076923076923077
# ROC-AUC: 0.9632523148148148
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       128
#            1       0.84      0.78      0.81        27
#
#     accuracy                           0.94       155
#    macro avg       0.90      0.87      0.88       155
# weighted avg       0.93      0.94      0.93       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)

# %% [markdown]
# 2.325396992846268

# %%
# test_preds = voting_classifier.predict_proba(test1)
# test_preds

# %%
# # test_preds = voting_classifier.predict_proba(test1)
# test_preds
# submit = pd.DataFrame({'Id':df_test['Id'], 'class_0': test_preds[:, 0], 'class_1': test_preds[:, 1]})
# submit

# %%
# submit.to_csv('/kaggle/working/submission.csv', index=False)
# submit=pd.read_csv("/kaggle/working/submission.csv")
# submit.head()

# %%
X_test.shape

# %% [markdown]
# # Stack

# %%
from sklearn.ensemble import StackingClassifier


rf = rf_model

xgb = xgb_model

catboost = catboost_model

gb_boost = bagging_cat

lg_classifier = log_reg

#stacking classifier

estimators = [('rf', rf),
              ('xgb', xgb),
              ('cat', catboost),
              ('gb', gb_boost)]

stacking = StackingClassifier(estimators=estimators,
                              final_estimator=lg_classifier,
                              cv=4)

rf.fit(X_train, y_train)
print(f"Random forest model training Accuracy: {rf.score(X_train, y_train):0.2f}")
print(f"Random forest model test Accuracy: {rf.score(X_test, y_test):0.2f}")

xgb.fit(X_train, y_train)
print(f"\nXGBoost model training Accuracy: {xgb.score(X_train, y_train):0.2f}")
print(f"XGBoost model test Accuracy: {xgb.score(X_test, y_test):0.2f}")


gb_boost.fit(X_train, y_train)
print(f"\nCatBoost model training Accuracy: {gb_boost.score(X_train, y_train):0.2f}")
print(f"CatBoost model test Accuracy: {gb_boost.score(X_test, y_test):0.2f}")

catboost.fit(X_train, y_train)
print(f"\nCatBoost model training Accuracy: {catboost.score(X_train, y_train):0.2f}")
print(f"CatBoost model test Accuracy: {catboost.score(X_test, y_test):0.2f}")

stacking.fit(X_train, y_train)
print(f"\nStacking classifier training Accuracy: {stacking.score(X_train, y_train):0.2f}")
print(f"Stacking classifier test Accuracy: {stacking.score(X_test, y_test):0.2f}")
# Out:
# Random forest model training Accuracy: 1.00
# Random forest model test Accuracy: 0.91
#
# XGBoost model training Accuracy: 1.00
# XGBoost model test Accuracy: 0.92
# 0:	learn: 0.6075713	total: 4.48ms	remaining: 443ms
# 1:	learn: 0.5419651	total: 9.03ms	remaining: 442ms
# 2:	learn: 0.4649892	total: 13.5ms	remaining: 437ms
# 3:	learn: 0.4036531	total: 18.1ms	remaining: 435ms
# 4:	learn: 0.3650346	total: 24.4ms	remaining: 464ms
# 5:	learn: 0.3331446	total: 29.4ms	remaining: 461ms
# 6:	learn: 0.2950778	total: 33.6ms	remaining: 447ms
# 7:	learn: 0.2667211	total: 37.9ms	remaining: 436ms
# 8:	learn: 0.2425027	total: 42.2ms	remaining: 426ms
# 9:	learn: 0.2301782	total: 46.6ms	remaining: 420ms
# 10:	learn: 0.2130236	total: 50.7ms	remaining: 410ms
# 11:	learn: 0.1980975	total: 54.8ms	remaining: 402ms
# 12:	learn: 0.1867005	total: 58.9ms	remaining: 394ms
# 13:	learn: 0.1753575	total: 62.9ms	remaining: 387ms
# 14:	learn: 0.1625547	total: 67.2ms	remaining: 381ms
# 15:	learn: 0.1524652	total: 71.5ms	remaining: 375ms
# 16:	learn: 0.1454715	total: 75.6ms	remaining: 369ms
# 17:	learn: 0.1386735	total: 79.4ms	remaining: 362ms
# 18:	learn: 0.1333822	total: 83.3ms	remaining: 355ms
# 19:	learn: 0.1287383	total: 87.6ms	remaining: 350ms
# 20:	learn: 0.1221222	total: 91.7ms	remaining: 345ms
# 21:	learn: 0.1168367	total: 95.7ms	remaining: 339ms
# 22:	learn: 0.1108355	total: 99.7ms	remaining: 334ms
# 23:	learn: 0.1068869	total: 104ms	remaining: 328ms
# 24:	learn: 0.1018652	total: 108ms	remaining: 323ms
# 25:	learn: 0.0978081	total: 112ms	remaining: 319ms
# 26:	learn: 0.0935395	total: 116ms	remaining: 314ms
# 27:	learn: 0.0896803	total: 121ms	remaining: 310ms
# 28:	learn: 0.0859696	total: 125ms	remaining: 307ms
# 29:	learn: 0.0827591	total: 131ms	remaining: 305ms
# 30:	learn: 0.0797530	total: 136ms	remaining: 302ms
# 31:	learn: 0.0765833	total: 141ms	remaining: 299ms
# 32:	learn: 0.0718496	total: 145ms	remaining: 294ms
# 33:	learn: 0.0681608	total: 149ms	remaining: 289ms
# 34:	learn: 0.0667960	total: 153ms	remaining: 285ms
# 35:	learn: 0.0634946	total: 157ms	remaining: 280ms
# 36:	learn: 0.0615925	total: 162ms	remaining: 275ms
# 37:	learn: 0.0585460	total: 166ms	remaining: 270ms
# 38:	learn: 0.0559112	total: 170ms	remaining: 266ms
# 39:	learn: 0.0541424	total: 174ms	remaining: 261ms
# 40:	learn: 0.0516072	total: 178ms	remaining: 256ms
# 41:	learn: 0.0495626	total: 182ms	remaining: 252ms
# 42:	learn: 0.0477960	total: 186ms	remaining: 247ms
# 43:	learn: 0.0456952	total: 191ms	remaining: 243ms
# 44:	learn: 0.0443886	total: 195ms	remaining: 238ms
# 45:	learn: 0.0429104	total: 199ms	remaining: 234ms
# 46:	learn: 0.0417957	total: 204ms	remaining: 230ms
# 47:	learn: 0.0405548	total: 208ms	remaining: 225ms
# 48:	learn: 0.0392400	total: 212ms	remaining: 221ms
# 49:	learn: 0.0379353	total: 216ms	remaining: 216ms
# 50:	learn: 0.0369293	total: 221ms	remaining: 213ms
# 51:	learn: 0.0357999	total: 226ms	remaining: 209ms
# 52:	learn: 0.0343988	total: 230ms	remaining: 204ms
# 53:	learn: 0.0336039	total: 235ms	remaining: 200ms
# 54:	learn: 0.0327726	total: 239ms	remaining: 195ms
# 55:	learn: 0.0316551	total: 244ms	remaining: 191ms
# 56:	learn: 0.0304499	total: 248ms	remaining: 187ms
# 57:	learn: 0.0294634	total: 252ms	remaining: 183ms
# 58:	learn: 0.0286748	total: 257ms	remaining: 178ms
# 59:	learn: 0.0277719	total: 261ms	remaining: 174ms
# 60:	learn: 0.0272308	total: 265ms	remaining: 170ms
# 61:	learn: 0.0264044	total: 269ms	remaining: 165ms
# 62:	learn: 0.0256609	total: 274ms	remaining: 161ms
# 63:	learn: 0.0249929	total: 278ms	remaining: 156ms
# 64:	learn: 0.0245636	total: 282ms	remaining: 152ms
# 65:	learn: 0.0236394	total: 286ms	remaining: 147ms
# 66:	learn: 0.0231678	total: 290ms	remaining: 143ms
# 67:	learn: 0.0224812	total: 295ms	remaining: 139ms
# 68:	learn: 0.0219837	total: 299ms	remaining: 134ms
# 69:	learn: 0.0214860	total: 303ms	remaining: 130ms
# 70:	learn: 0.0210900	total: 307ms	remaining: 126ms
# 71:	learn: 0.0208167	total: 311ms	remaining: 121ms
# 72:	learn: 0.0202785	total: 316ms	remaining: 117ms
# 73:	learn: 0.0197324	total: 320ms	remaining: 112ms
# 74:	learn: 0.0191145	total: 325ms	remaining: 108ms
# 75:	learn: 0.0186499	total: 329ms	remaining: 104ms
# 76:	learn: 0.0181422	total: 333ms	remaining: 99.5ms
# 77:	learn: 0.0175613	total: 337ms	remaining: 95.1ms
# 78:	learn: 0.0168455	total: 342ms	remaining: 90.8ms
# 79:	learn: 0.0163549	total: 346ms	remaining: 86.5ms
# 80:	learn: 0.0159165	total: 350ms	remaining: 82.1ms
# 81:	learn: 0.0153882	total: 354ms	remaining: 77.8ms
# 82:	learn: 0.0150279	total: 358ms	remaining: 73.4ms
# 83:	learn: 0.0147004	total: 363ms	remaining: 69.1ms
# 84:	learn: 0.0142837	total: 367ms	remaining: 64.8ms
# 85:	learn: 0.0139449	total: 371ms	remaining: 60.5ms
# 86:	learn: 0.0137591	total: 376ms	remaining: 56.1ms
# 87:	learn: 0.0134944	total: 380ms	remaining: 51.8ms
# 88:	learn: 0.0132089	total: 385ms	remaining: 47.5ms
# 89:	learn: 0.0129159	total: 389ms	remaining: 43.2ms
# 90:	learn: 0.0126362	total: 393ms	remaining: 38.8ms
# 91:	learn: 0.0123685	total: 397ms	remaining: 34.5ms
# 92:	learn: 0.0121113	total: 401ms	remaining: 30.2ms
# 93:	learn: 0.0118977	total: 406ms	remaining: 25.9ms
# 94:	learn: 0.0116224	total: 411ms	remaining: 21.6ms
# 95:	learn: 0.0116128	total: 415ms	remaining: 17.3ms
# 96:	learn: 0.0113649	total: 422ms	remaining: 13.1ms
# 97:	learn: 0.0111598	total: 428ms	remaining: 8.73ms
# 98:	learn: 0.0109784	total: 432ms	remaining: 4.37ms
# 99:	learn: 0.0107334	total: 437ms	remaining: 0us
# 0:	learn: 0.6138595	total: 4.04ms	remaining: 400ms
# 1:	learn: 0.5362926	total: 8.19ms	remaining: 401ms
# 2:	learn: 0.4658423	total: 12ms	remaining: 388ms
# 3:	learn: 0.4252953	total: 16.1ms	remaining: 387ms
# 4:	learn: 0.3737007	total: 19.8ms	remaining: 376ms
# 5:	learn: 0.3400397	total: 23.5ms	remaining: 368ms
# 6:	learn: 0.3099714	total: 27ms	remaining: 359ms
# 7:	learn: 0.2752783	total: 30.5ms	remaining: 351ms
# 8:	learn: 0.2572672	total: 34ms	remaining: 344ms
# 9:	learn: 0.2351024	total: 37.6ms	remaining: 338ms
# 10:	learn: 0.2173806	total: 41.4ms	remaining: 335ms
# 11:	learn: 0.2040808	total: 45.3ms	remaining: 332ms
# 12:	learn: 0.1913623	total: 48.9ms	remaining: 328ms
# 13:	learn: 0.1800099	total: 52.9ms	remaining: 325ms
# 14:	learn: 0.1673228	total: 56.7ms	remaining: 321ms
# 15:	learn: 0.1548751	total: 60.3ms	remaining: 317ms
# 16:	learn: 0.1462350	total: 64ms	remaining: 312ms
# 17:	learn: 0.1435578	total: 67.8ms	remaining: 309ms
# 18:	learn: 0.1374453	total: 71.5ms	remaining: 305ms
# 19:	learn: 0.1309721	total: 75.3ms	remaining: 301ms
# 20:	learn: 0.1249082	total: 79.4ms	remaining: 299ms
# 21:	learn: 0.1205019	total: 83.1ms	remaining: 295ms
# 22:	learn: 0.1150313	total: 86.8ms	remaining: 291ms
# 23:	learn: 0.1115641	total: 90.5ms	remaining: 286ms
# 24:	learn: 0.1051142	total: 94.2ms	remaining: 282ms
# 25:	learn: 0.1023438	total: 97.9ms	remaining: 279ms
# 26:	learn: 0.0965467	total: 102ms	remaining: 275ms
# 27:	learn: 0.0917047	total: 105ms	remaining: 271ms
# 28:	learn: 0.0866123	total: 109ms	remaining: 267ms
# 29:	learn: 0.0833025	total: 113ms	remaining: 263ms
# 30:	learn: 0.0809257	total: 116ms	remaining: 259ms
# 31:	learn: 0.0773987	total: 120ms	remaining: 255ms
# 32:	learn: 0.0737638	total: 123ms	remaining: 251ms
# 33:	learn: 0.0713637	total: 127ms	remaining: 247ms
# 34:	learn: 0.0697120	total: 131ms	remaining: 242ms
# 35:	learn: 0.0661542	total: 134ms	remaining: 239ms
# 36:	learn: 0.0641633	total: 138ms	remaining: 235ms
# 37:	learn: 0.0611547	total: 142ms	remaining: 232ms
# 38:	learn: 0.0595071	total: 146ms	remaining: 228ms
# 39:	learn: 0.0586922	total: 151ms	remaining: 226ms
# 40:	learn: 0.0574333	total: 155ms	remaining: 224ms
# 41:	learn: 0.0545301	total: 159ms	remaining: 220ms
# 42:	learn: 0.0537186	total: 163ms	remaining: 216ms
# 43:	learn: 0.0515057	total: 167ms	remaining: 212ms
# 44:	learn: 0.0507600	total: 170ms	remaining: 208ms
# 45:	learn: 0.0486805	total: 174ms	remaining: 204ms
# 46:	learn: 0.0471455	total: 178ms	remaining: 200ms
# 47:	learn: 0.0462412	total: 182ms	remaining: 197ms
# 48:	learn: 0.0445635	total: 185ms	remaining: 193ms
# 49:	learn: 0.0418947	total: 189ms	remaining: 189ms
# 50:	learn: 0.0407849	total: 193ms	remaining: 186ms
# 51:	learn: 0.0401370	total: 197ms	remaining: 182ms
# 52:	learn: 0.0393909	total: 201ms	remaining: 178ms
# 53:	learn: 0.0382527	total: 205ms	remaining: 174ms
# 54:	learn: 0.0374118	total: 208ms	remaining: 171ms
# 55:	learn: 0.0361593	total: 213ms	remaining: 167ms
# 56:	learn: 0.0352189	total: 217ms	remaining: 164ms
# 57:	learn: 0.0344805	total: 221ms	remaining: 160ms
# 58:	learn: 0.0332138	total: 224ms	remaining: 156ms
# 59:	learn: 0.0324207	total: 228ms	remaining: 152ms
# 60:	learn: 0.0317776	total: 232ms	remaining: 148ms
# 61:	learn: 0.0307470	total: 236ms	remaining: 145ms
# 62:	learn: 0.0299218	total: 240ms	remaining: 141ms
# 63:	learn: 0.0291787	total: 244ms	remaining: 137ms
# 64:	learn: 0.0278429	total: 248ms	remaining: 133ms
# 65:	learn: 0.0271142	total: 252ms	remaining: 130ms
# 66:	learn: 0.0265214	total: 257ms	remaining: 127ms
# 67:	learn: 0.0259694	total: 261ms	remaining: 123ms
# 68:	learn: 0.0257825	total: 266ms	remaining: 119ms
# 69:	learn: 0.0252409	total: 270ms	remaining: 116ms
# 70:	learn: 0.0248063	total: 274ms	remaining: 112ms
# 71:	learn: 0.0237472	total: 277ms	remaining: 108ms
# 72:	learn: 0.0230654	total: 281ms	remaining: 104ms
# 73:	learn: 0.0225921	total: 285ms	remaining: 100ms
# 74:	learn: 0.0221300	total: 289ms	remaining: 96.3ms
# 75:	learn: 0.0217681	total: 292ms	remaining: 92.4ms
# 76:	learn: 0.0212455	total: 296ms	remaining: 88.5ms
# 77:	learn: 0.0207055	total: 300ms	remaining: 84.6ms
# 78:	learn: 0.0200613	total: 304ms	remaining: 80.8ms
# 79:	learn: 0.0193347	total: 308ms	remaining: 76.9ms
# 80:	learn: 0.0189940	total: 312ms	remaining: 73.1ms
# 81:	learn: 0.0187955	total: 315ms	remaining: 69.2ms
# 82:	learn: 0.0182773	total: 319ms	remaining: 65.3ms
# 83:	learn: 0.0179589	total: 323ms	remaining: 61.5ms
# 84:	learn: 0.0174975	total: 326ms	remaining: 57.6ms
# 85:	learn: 0.0171565	total: 330ms	remaining: 53.8ms
# 86:	learn: 0.0168421	total: 334ms	remaining: 49.9ms
# 87:	learn: 0.0163116	total: 338ms	remaining: 46ms
# 88:	learn: 0.0160498	total: 341ms	remaining: 42.2ms
# 89:	learn: 0.0157933	total: 346ms	remaining: 38.4ms
# 90:	learn: 0.0156250	total: 351ms	remaining: 34.7ms
# 91:	learn: 0.0153160	total: 355ms	remaining: 30.9ms
# 92:	learn: 0.0151278	total: 359ms	remaining: 27ms
# 93:	learn: 0.0146563	total: 363ms	remaining: 23.1ms
# 94:	learn: 0.0143755	total: 366ms	remaining: 19.3ms
# 95:	learn: 0.0140756	total: 370ms	remaining: 15.4ms
# 96:	learn: 0.0138682	total: 374ms	remaining: 11.6ms
# 97:	learn: 0.0135943	total: 377ms	remaining: 7.7ms
# 98:	learn: 0.0133194	total: 381ms	remaining: 3.85ms
# 99:	learn: 0.0131288	total: 385ms	remaining: 0us
# 0:	learn: 0.6342665	total: 4.04ms	remaining: 400ms
# 1:	learn: 0.5739098	total: 7.93ms	remaining: 389ms
# 2:	learn: 0.5104666	total: 11.7ms	remaining: 378ms
# 3:	learn: 0.4553676	total: 15.5ms	remaining: 372ms
# 4:	learn: 0.4067672	total: 20.2ms	remaining: 384ms
# 5:	learn: 0.3716710	total: 24.4ms	remaining: 382ms
# 6:	learn: 0.3399316	total: 28.1ms	remaining: 373ms
# 7:	learn: 0.3172317	total: 32ms	remaining: 368ms
# 8:	learn: 0.2916738	total: 35.8ms	remaining: 362ms
# 9:	learn: 0.2821779	total: 39.6ms	remaining: 357ms
# 10:	learn: 0.2625236	total: 43.2ms	remaining: 349ms
# 11:	learn: 0.2516208	total: 47ms	remaining: 345ms
# 12:	learn: 0.2417054	total: 50.9ms	remaining: 341ms
# 13:	learn: 0.2310105	total: 54.8ms	remaining: 336ms
# 14:	learn: 0.2171687	total: 58.7ms	remaining: 333ms
# 15:	learn: 0.2076472	total: 62.5ms	remaining: 328ms
# 16:	learn: 0.1993349	total: 69.2ms	remaining: 338ms
# 17:	learn: 0.1898600	total: 74.4ms	remaining: 339ms
# 18:	learn: 0.1820859	total: 80.9ms	remaining: 345ms
# 19:	learn: 0.1744160	total: 84.8ms	remaining: 339ms
# 20:	learn: 0.1667630	total: 88.6ms	remaining: 333ms
# 21:	learn: 0.1584719	total: 92.5ms	remaining: 328ms
# 22:	learn: 0.1516218	total: 96.4ms	remaining: 323ms
# 23:	learn: 0.1469867	total: 100ms	remaining: 317ms
# 24:	learn: 0.1408214	total: 104ms	remaining: 312ms
# 25:	learn: 0.1351311	total: 108ms	remaining: 307ms
# 26:	learn: 0.1282224	total: 112ms	remaining: 302ms
# 27:	learn: 0.1230574	total: 116ms	remaining: 297ms
# 28:	learn: 0.1173974	total: 119ms	remaining: 292ms
# 29:	learn: 0.1117577	total: 123ms	remaining: 288ms
# 30:	learn: 0.1082679	total: 127ms	remaining: 283ms
# 31:	learn: 0.1029475	total: 132ms	remaining: 280ms
# 32:	learn: 0.0989698	total: 136ms	remaining: 277ms
# 33:	learn: 0.0939784	total: 141ms	remaining: 273ms
# 34:	learn: 0.0913182	total: 145ms	remaining: 268ms
# 35:	learn: 0.0874871	total: 148ms	remaining: 264ms
# 36:	learn: 0.0833839	total: 152ms	remaining: 259ms
# 37:	learn: 0.0805291	total: 156ms	remaining: 254ms
# 38:	learn: 0.0779899	total: 160ms	remaining: 250ms
# 39:	learn: 0.0755352	total: 164ms	remaining: 245ms
# 40:	learn: 0.0738493	total: 167ms	remaining: 241ms
# 41:	learn: 0.0713699	total: 171ms	remaining: 236ms
# 42:	learn: 0.0690073	total: 175ms	remaining: 232ms
# 43:	learn: 0.0668890	total: 181ms	remaining: 230ms
# 44:	learn: 0.0653616	total: 185ms	remaining: 226ms
# 45:	learn: 0.0629104	total: 189ms	remaining: 221ms
# 46:	learn: 0.0605929	total: 192ms	remaining: 217ms
# 47:	learn: 0.0585151	total: 198ms	remaining: 215ms
# 48:	learn: 0.0570860	total: 205ms	remaining: 213ms
# 49:	learn: 0.0551540	total: 211ms	remaining: 211ms
# 50:	learn: 0.0531406	total: 215ms	remaining: 207ms
# 51:	learn: 0.0512004	total: 220ms	remaining: 203ms
# 52:	learn: 0.0494669	total: 225ms	remaining: 200ms
# 53:	learn: 0.0478494	total: 230ms	remaining: 196ms
# 54:	learn: 0.0465195	total: 235ms	remaining: 192ms
# 55:	learn: 0.0452290	total: 240ms	remaining: 189ms
# 56:	learn: 0.0440267	total: 249ms	remaining: 188ms
# 57:	learn: 0.0433403	total: 256ms	remaining: 186ms
# 58:	learn: 0.0422142	total: 262ms	remaining: 182ms
# 59:	learn: 0.0405567	total: 266ms	remaining: 178ms
# 60:	learn: 0.0389393	total: 271ms	remaining: 173ms
# 61:	learn: 0.0374868	total: 277ms	remaining: 170ms
# 62:	learn: 0.0362538	total: 282ms	remaining: 166ms
# 63:	learn: 0.0355033	total: 289ms	remaining: 163ms
# 64:	learn: 0.0344016	total: 295ms	remaining: 159ms
# 65:	learn: 0.0335553	total: 300ms	remaining: 154ms
# 66:	learn: 0.0326912	total: 304ms	remaining: 150ms
# 67:	learn: 0.0315775	total: 308ms	remaining: 145ms
# 68:	learn: 0.0308159	total: 311ms	remaining: 140ms
# 69:	learn: 0.0299186	total: 315ms	remaining: 135ms
# 70:	learn: 0.0291733	total: 319ms	remaining: 130ms
# 71:	learn: 0.0283739	total: 323ms	remaining: 126ms
# 72:	learn: 0.0277008	total: 326ms	remaining: 121ms
# 73:	learn: 0.0269320	total: 331ms	remaining: 116ms
# 74:	learn: 0.0262457	total: 336ms	remaining: 112ms
# 75:	learn: 0.0256111	total: 340ms	remaining: 107ms
# 76:	learn: 0.0248626	total: 344ms	remaining: 103ms
# 77:	learn: 0.0240854	total: 348ms	remaining: 98.1ms
# 78:	learn: 0.0232773	total: 352ms	remaining: 93.4ms
# 79:	learn: 0.0226962	total: 355ms	remaining: 88.8ms
# 80:	learn: 0.0220218	total: 360ms	remaining: 84.3ms
# 81:	learn: 0.0213997	total: 363ms	remaining: 79.7ms
# 82:	learn: 0.0209811	total: 367ms	remaining: 75.2ms
# 83:	learn: 0.0203290	total: 371ms	remaining: 70.7ms
# 84:	learn: 0.0196210	total: 375ms	remaining: 66.2ms
# 85:	learn: 0.0190633	total: 379ms	remaining: 61.7ms
# 86:	learn: 0.0185912	total: 383ms	remaining: 57.2ms
# 87:	learn: 0.0181022	total: 386ms	remaining: 52.7ms
# 88:	learn: 0.0176917	total: 390ms	remaining: 48.2ms
# 89:	learn: 0.0172798	total: 394ms	remaining: 43.8ms
# 90:	learn: 0.0167311	total: 398ms	remaining: 39.4ms
# 91:	learn: 0.0163848	total: 402ms	remaining: 35ms
# 92:	learn: 0.0160046	total: 406ms	remaining: 30.6ms
# 93:	learn: 0.0157100	total: 410ms	remaining: 26.2ms
# 94:	learn: 0.0153478	total: 414ms	remaining: 21.8ms
# 95:	learn: 0.0149892	total: 418ms	remaining: 17.4ms
# 96:	learn: 0.0146617	total: 421ms	remaining: 13ms
# 97:	learn: 0.0142811	total: 425ms	remaining: 8.68ms
# 98:	learn: 0.0139128	total: 430ms	remaining: 4.34ms
# 99:	learn: 0.0135715	total: 434ms	remaining: 0us
# 0:	learn: 0.6232592	total: 4.5ms	remaining: 446ms
# 1:	learn: 0.5804215	total: 8.79ms	remaining: 431ms
# 2:	learn: 0.5207626	total: 13.1ms	remaining: 425ms
# 3:	learn: 0.4617573	total: 17.4ms	remaining: 416ms
# 4:	learn: 0.4288866	total: 21.6ms	remaining: 410ms
# 5:	learn: 0.3982095	total: 25.7ms	remaining: 403ms
# 6:	learn: 0.3602658	total: 30.1ms	remaining: 399ms
# 7:	learn: 0.3357621	total: 34ms	remaining: 392ms
# 8:	learn: 0.3229907	total: 38ms	remaining: 384ms
# 9:	learn: 0.2990993	total: 42ms	remaining: 378ms
# 10:	learn: 0.2773350	total: 46.1ms	remaining: 373ms
# 11:	learn: 0.2619504	total: 50.4ms	remaining: 370ms
# 12:	learn: 0.2481769	total: 54.5ms	remaining: 365ms
# 13:	learn: 0.2348025	total: 58.5ms	remaining: 359ms
# 14:	learn: 0.2235829	total: 62.5ms	remaining: 354ms
# 15:	learn: 0.2117960	total: 67.2ms	remaining: 353ms
# 16:	learn: 0.1987823	total: 72.2ms	remaining: 352ms
# 17:	learn: 0.1858564	total: 76.6ms	remaining: 349ms
# 18:	learn: 0.1739709	total: 80.7ms	remaining: 344ms
# 19:	learn: 0.1693756	total: 84.5ms	remaining: 338ms
# 20:	learn: 0.1632753	total: 88.8ms	remaining: 334ms
# 21:	learn: 0.1565140	total: 93.1ms	remaining: 330ms
# 22:	learn: 0.1526851	total: 97.3ms	remaining: 326ms
# 23:	learn: 0.1482194	total: 101ms	remaining: 320ms
# 24:	learn: 0.1428804	total: 105ms	remaining: 315ms
# 25:	learn: 0.1378345	total: 109ms	remaining: 310ms
# 26:	learn: 0.1341617	total: 113ms	remaining: 305ms
# 27:	learn: 0.1283883	total: 117ms	remaining: 301ms
# 28:	learn: 0.1213145	total: 121ms	remaining: 296ms
# 29:	learn: 0.1164491	total: 125ms	remaining: 291ms
# 30:	learn: 0.1112192	total: 129ms	remaining: 286ms
# 31:	learn: 0.1071114	total: 134ms	remaining: 284ms
# 32:	learn: 0.1022234	total: 139ms	remaining: 282ms
# 33:	learn: 0.0992318	total: 144ms	remaining: 280ms
# 34:	learn: 0.0942086	total: 149ms	remaining: 277ms
# 35:	learn: 0.0901911	total: 154ms	remaining: 274ms
# 36:	learn: 0.0880438	total: 160ms	remaining: 272ms
# 37:	learn: 0.0840276	total: 166ms	remaining: 270ms
# 38:	learn: 0.0797335	total: 171ms	remaining: 267ms
# 39:	learn: 0.0763719	total: 176ms	remaining: 263ms
# 40:	learn: 0.0742691	total: 181ms	remaining: 260ms
# 41:	learn: 0.0711638	total: 185ms	remaining: 255ms
# 42:	learn: 0.0690856	total: 189ms	remaining: 250ms
# 43:	learn: 0.0674780	total: 193ms	remaining: 245ms
# 44:	learn: 0.0647922	total: 197ms	remaining: 240ms
# 45:	learn: 0.0627408	total: 201ms	remaining: 236ms
# 46:	learn: 0.0610603	total: 205ms	remaining: 231ms
# 47:	learn: 0.0593503	total: 209ms	remaining: 226ms
# 48:	learn: 0.0578734	total: 213ms	remaining: 222ms
# 49:	learn: 0.0557003	total: 217ms	remaining: 217ms
# 50:	learn: 0.0536942	total: 221ms	remaining: 212ms
# 51:	learn: 0.0518848	total: 225ms	remaining: 207ms
# 52:	learn: 0.0510894	total: 229ms	remaining: 203ms
# 53:	learn: 0.0497567	total: 233ms	remaining: 198ms
# 54:	learn: 0.0485608	total: 237ms	remaining: 194ms
# 55:	learn: 0.0467421	total: 241ms	remaining: 189ms
# 56:	learn: 0.0455315	total: 245ms	remaining: 185ms
# 57:	learn: 0.0443715	total: 249ms	remaining: 180ms
# 58:	learn: 0.0431940	total: 253ms	remaining: 176ms
# 59:	learn: 0.0412990	total: 257ms	remaining: 172ms
# 60:	learn: 0.0400195	total: 262ms	remaining: 168ms
# 61:	learn: 0.0386635	total: 266ms	remaining: 163ms
# 62:	learn: 0.0377036	total: 272ms	remaining: 160ms
# 63:	learn: 0.0367185	total: 276ms	remaining: 155ms
# 64:	learn: 0.0358948	total: 280ms	remaining: 151ms
# 65:	learn: 0.0344855	total: 284ms	remaining: 146ms
# 66:	learn: 0.0336271	total: 288ms	remaining: 142ms
# 67:	learn: 0.0328271	total: 292ms	remaining: 137ms
# 68:	learn: 0.0316137	total: 296ms	remaining: 133ms
# 69:	learn: 0.0308111	total: 300ms	remaining: 129ms
# 70:	learn: 0.0298903	total: 304ms	remaining: 124ms
# 71:	learn: 0.0289496	total: 308ms	remaining: 120ms
# 72:	learn: 0.0280620	total: 312ms	remaining: 115ms
# 73:	learn: 0.0274367	total: 316ms	remaining: 111ms
# 74:	learn: 0.0266043	total: 320ms	remaining: 107ms
# 75:	learn: 0.0255828	total: 324ms	remaining: 102ms
# 76:	learn: 0.0250745	total: 328ms	remaining: 97.9ms
# 77:	learn: 0.0242932	total: 332ms	remaining: 93.6ms
# 78:	learn: 0.0237009	total: 336ms	remaining: 89.2ms
# 79:	learn: 0.0230316	total: 340ms	remaining: 84.9ms
# 80:	learn: 0.0222354	total: 344ms	remaining: 80.6ms
# 81:	learn: 0.0216881	total: 348ms	remaining: 76.3ms
# 82:	learn: 0.0210234	total: 352ms	remaining: 72ms
# 83:	learn: 0.0204999	total: 355ms	remaining: 67.7ms
# 84:	learn: 0.0198669	total: 360ms	remaining: 63.4ms
# 85:	learn: 0.0193647	total: 364ms	remaining: 59.2ms
# 86:	learn: 0.0188930	total: 368ms	remaining: 55ms
# 87:	learn: 0.0184284	total: 372ms	remaining: 50.7ms
# 88:	learn: 0.0179820	total: 376ms	remaining: 46.4ms
# 89:	learn: 0.0175465	total: 380ms	remaining: 42.2ms
# 90:	learn: 0.0173259	total: 384ms	remaining: 37.9ms
# 91:	learn: 0.0169740	total: 387ms	remaining: 33.7ms
# 92:	learn: 0.0166617	total: 391ms	remaining: 29.5ms
# 93:	learn: 0.0164513	total: 395ms	remaining: 25.2ms
# 94:	learn: 0.0160852	total: 399ms	remaining: 21ms
# 95:	learn: 0.0158040	total: 403ms	remaining: 16.8ms
# 96:	learn: 0.0154593	total: 407ms	remaining: 12.6ms
# 97:	learn: 0.0152680	total: 411ms	remaining: 8.38ms
# 98:	learn: 0.0148766	total: 415ms	remaining: 4.19ms
# 99:	learn: 0.0146547	total: 419ms	remaining: 0us
# 0:	learn: 0.5905132	total: 4.08ms	remaining: 404ms
# 1:	learn: 0.5250251	total: 7.93ms	remaining: 389ms
# 2:	learn: 0.4558458	total: 11.7ms	remaining: 379ms
# 3:	learn: 0.4112553	total: 16ms	remaining: 384ms
# 4:	learn: 0.3759999	total: 20.1ms	remaining: 381ms
# 5:	learn: 0.3473735	total: 24.9ms	remaining: 389ms
# 6:	learn: 0.3234365	total: 29.2ms	remaining: 388ms
# 7:	learn: 0.2916076	total: 33.4ms	remaining: 384ms
# 8:	learn: 0.2650925	total: 37ms	remaining: 375ms
# 9:	learn: 0.2417433	total: 40.8ms	remaining: 367ms
# 10:	learn: 0.2302786	total: 44.4ms	remaining: 360ms
# 11:	learn: 0.2160401	total: 48.2ms	remaining: 353ms
# 12:	learn: 0.1976591	total: 52ms	remaining: 348ms
# 13:	learn: 0.1829915	total: 55.9ms	remaining: 343ms
# 14:	learn: 0.1723569	total: 59.5ms	remaining: 337ms
# 15:	learn: 0.1633205	total: 63.1ms	remaining: 332ms
# 16:	learn: 0.1546566	total: 67.1ms	remaining: 327ms
# 17:	learn: 0.1421464	total: 70.9ms	remaining: 323ms
# 18:	learn: 0.1359221	total: 74.7ms	remaining: 318ms
# 19:	learn: 0.1286656	total: 78.6ms	remaining: 314ms
# 20:	learn: 0.1221269	total: 82.4ms	remaining: 310ms
# 21:	learn: 0.1158658	total: 87.3ms	remaining: 310ms
# 22:	learn: 0.1110268	total: 91.3ms	remaining: 306ms
# 23:	learn: 0.1073202	total: 95.4ms	remaining: 302ms
# 24:	learn: 0.1038781	total: 99.3ms	remaining: 298ms
# 25:	learn: 0.0981320	total: 103ms	remaining: 293ms
# 26:	learn: 0.0960517	total: 107ms	remaining: 289ms
# 27:	learn: 0.0923741	total: 111ms	remaining: 284ms
# 28:	learn: 0.0875746	total: 115ms	remaining: 281ms
# 29:	learn: 0.0849876	total: 118ms	remaining: 276ms
# 30:	learn: 0.0818182	total: 122ms	remaining: 272ms
# 31:	learn: 0.0782733	total: 126ms	remaining: 268ms
# 32:	learn: 0.0742447	total: 130ms	remaining: 264ms
# 33:	learn: 0.0723621	total: 134ms	remaining: 259ms
# 34:	learn: 0.0690375	total: 138ms	remaining: 256ms
# 35:	learn: 0.0667182	total: 141ms	remaining: 252ms
# 36:	learn: 0.0649634	total: 145ms	remaining: 248ms
# 37:	learn: 0.0633522	total: 149ms	remaining: 243ms
# 38:	learn: 0.0609424	total: 153ms	remaining: 239ms
# 39:	learn: 0.0597975	total: 157ms	remaining: 235ms
# 40:	learn: 0.0574929	total: 161ms	remaining: 231ms
# 41:	learn: 0.0557906	total: 164ms	remaining: 227ms
# 42:	learn: 0.0545643	total: 168ms	remaining: 223ms
# 43:	learn: 0.0536385	total: 172ms	remaining: 219ms
# 44:	learn: 0.0521006	total: 176ms	remaining: 215ms
# 45:	learn: 0.0507296	total: 179ms	remaining: 211ms
# 46:	learn: 0.0491240	total: 183ms	remaining: 206ms
# 47:	learn: 0.0479483	total: 187ms	remaining: 202ms
# 48:	learn: 0.0462579	total: 191ms	remaining: 198ms
# 49:	learn: 0.0451277	total: 195ms	remaining: 195ms
# 50:	learn: 0.0435926	total: 198ms	remaining: 191ms
# 51:	learn: 0.0422473	total: 202ms	remaining: 187ms
# 52:	learn: 0.0416360	total: 206ms	remaining: 183ms
# 53:	learn: 0.0403862	total: 210ms	remaining: 179ms
# 54:	learn: 0.0389225	total: 214ms	remaining: 175ms
# 55:	learn: 0.0379480	total: 218ms	remaining: 171ms
# 56:	learn: 0.0367395	total: 223ms	remaining: 168ms
# 57:	learn: 0.0357865	total: 227ms	remaining: 164ms
# 58:	learn: 0.0347890	total: 231ms	remaining: 160ms
# 59:	learn: 0.0338370	total: 234ms	remaining: 156ms
# 60:	learn: 0.0325960	total: 238ms	remaining: 152ms
# 61:	learn: 0.0314182	total: 242ms	remaining: 148ms
# 62:	learn: 0.0306004	total: 246ms	remaining: 144ms
# 63:	learn: 0.0300924	total: 250ms	remaining: 140ms
# 64:	learn: 0.0293083	total: 253ms	remaining: 136ms
# 65:	learn: 0.0284769	total: 257ms	remaining: 133ms
# 66:	learn: 0.0279493	total: 262ms	remaining: 129ms
# 67:	learn: 0.0269483	total: 265ms	remaining: 125ms
# 68:	learn: 0.0265141	total: 269ms	remaining: 121ms
# 69:	learn: 0.0256932	total: 273ms	remaining: 117ms
# 70:	learn: 0.0251032	total: 277ms	remaining: 113ms
# 71:	learn: 0.0242674	total: 281ms	remaining: 109ms
# 72:	learn: 0.0236640	total: 285ms	remaining: 105ms
# 73:	learn: 0.0230435	total: 289ms	remaining: 102ms
# 74:	learn: 0.0228044	total: 293ms	remaining: 97.6ms
# 75:	learn: 0.0220517	total: 297ms	remaining: 93.7ms
# 76:	learn: 0.0219405	total: 301ms	remaining: 89.8ms
# 77:	learn: 0.0218193	total: 305ms	remaining: 85.9ms
# 78:	learn: 0.0212499	total: 309ms	remaining: 82.1ms
# 79:	learn: 0.0206058	total: 313ms	remaining: 78.2ms
# 80:	learn: 0.0202190	total: 317ms	remaining: 74.3ms
# 81:	learn: 0.0199190	total: 320ms	remaining: 70.3ms
# 82:	learn: 0.0191271	total: 324ms	remaining: 66.4ms
# 83:	learn: 0.0186300	total: 328ms	remaining: 62.5ms
# 84:	learn: 0.0182084	total: 332ms	remaining: 58.6ms
# 85:	learn: 0.0180911	total: 336ms	remaining: 54.7ms
# 86:	learn: 0.0173796	total: 340ms	remaining: 50.8ms
# 87:	learn: 0.0171330	total: 344ms	remaining: 46.9ms
# 88:	learn: 0.0170533	total: 348ms	remaining: 43ms
# 89:	learn: 0.0169575	total: 352ms	remaining: 39.1ms
# 90:	learn: 0.0169208	total: 355ms	remaining: 35.2ms
# 91:	learn: 0.0165317	total: 359ms	remaining: 31.2ms
# 92:	learn: 0.0162097	total: 363ms	remaining: 27.3ms
# 93:	learn: 0.0161200	total: 367ms	remaining: 23.4ms
# 94:	learn: 0.0156727	total: 371ms	remaining: 19.5ms
# 95:	learn: 0.0152511	total: 374ms	remaining: 15.6ms
# 96:	learn: 0.0150152	total: 378ms	remaining: 11.7ms
# 97:	learn: 0.0146708	total: 382ms	remaining: 7.8ms
# 98:	learn: 0.0144530	total: 386ms	remaining: 3.9ms
# 99:	learn: 0.0140161	total: 390ms	remaining: 0us
# 0:	learn: 0.6062376	total: 4.93ms	remaining: 488ms
# 1:	learn: 0.5334682	total: 9.43ms	remaining: 462ms
# 2:	learn: 0.4658435	total: 13.5ms	remaining: 436ms
# 3:	learn: 0.4101051	total: 17.5ms	remaining: 421ms
# 4:	learn: 0.3733603	total: 21.5ms	remaining: 408ms
# 5:	learn: 0.3404326	total: 25.3ms	remaining: 396ms
# 6:	learn: 0.3159192	total: 29.2ms	remaining: 388ms
# 7:	learn: 0.2826560	total: 33ms	remaining: 380ms
# 8:	learn: 0.2592156	total: 36.8ms	remaining: 372ms
# 9:	learn: 0.2421014	total: 40.6ms	remaining: 365ms
# 10:	learn: 0.2210820	total: 44.5ms	remaining: 360ms
# 11:	learn: 0.2069763	total: 48.3ms	remaining: 354ms
# 12:	learn: 0.1917071	total: 52.2ms	remaining: 349ms
# 13:	learn: 0.1812531	total: 56.1ms	remaining: 345ms
# 14:	learn: 0.1704075	total: 59.9ms	remaining: 340ms
# 15:	learn: 0.1622061	total: 63.8ms	remaining: 335ms
# 16:	learn: 0.1558509	total: 67.6ms	remaining: 330ms
# 17:	learn: 0.1468753	total: 71.5ms	remaining: 326ms
# 18:	learn: 0.1408528	total: 75.4ms	remaining: 321ms
# 19:	learn: 0.1309765	total: 79.3ms	remaining: 317ms
# 20:	learn: 0.1240137	total: 83.3ms	remaining: 313ms
# 21:	learn: 0.1184520	total: 87.5ms	remaining: 310ms
# 22:	learn: 0.1139227	total: 91.4ms	remaining: 306ms
# 23:	learn: 0.1092857	total: 95.2ms	remaining: 302ms
# 24:	learn: 0.1042286	total: 99.1ms	remaining: 297ms
# 25:	learn: 0.1005907	total: 103ms	remaining: 293ms
# 26:	learn: 0.0967607	total: 107ms	remaining: 289ms
# 27:	learn: 0.0929982	total: 111ms	remaining: 285ms
# 28:	learn: 0.0894446	total: 115ms	remaining: 281ms
# 29:	learn: 0.0868776	total: 119ms	remaining: 277ms
# 30:	learn: 0.0849163	total: 123ms	remaining: 273ms
# 31:	learn: 0.0815229	total: 127ms	remaining: 269ms
# 32:	learn: 0.0766629	total: 131ms	remaining: 265ms
# 33:	learn: 0.0749719	total: 135ms	remaining: 261ms
# 34:	learn: 0.0726546	total: 139ms	remaining: 257ms
# 35:	learn: 0.0699277	total: 143ms	remaining: 253ms
# 36:	learn: 0.0666596	total: 147ms	remaining: 249ms
# 37:	learn: 0.0645462	total: 150ms	remaining: 245ms
# 38:	learn: 0.0627471	total: 154ms	remaining: 241ms
# 39:	learn: 0.0617068	total: 158ms	remaining: 237ms
# 40:	learn: 0.0600072	total: 162ms	remaining: 233ms
# 41:	learn: 0.0580791	total: 166ms	remaining: 229ms
# 42:	learn: 0.0562058	total: 170ms	remaining: 225ms
# 43:	learn: 0.0547730	total: 174ms	remaining: 221ms
# 44:	learn: 0.0530347	total: 177ms	remaining: 217ms
# 45:	learn: 0.0514349	total: 181ms	remaining: 213ms
# 46:	learn: 0.0497777	total: 185ms	remaining: 209ms
# 47:	learn: 0.0484928	total: 189ms	remaining: 205ms
# 48:	learn: 0.0470185	total: 193ms	remaining: 201ms
# 49:	learn: 0.0453709	total: 197ms	remaining: 197ms
# 50:	learn: 0.0443299	total: 202ms	remaining: 194ms
# 51:	learn: 0.0428497	total: 206ms	remaining: 190ms
# 52:	learn: 0.0417144	total: 210ms	remaining: 187ms
# 53:	learn: 0.0406968	total: 214ms	remaining: 182ms
# 54:	learn: 0.0393302	total: 218ms	remaining: 178ms
# 55:	learn: 0.0381887	total: 222ms	remaining: 174ms
# 56:	learn: 0.0373561	total: 226ms	remaining: 171ms
# 57:	learn: 0.0363170	total: 230ms	remaining: 167ms
# 58:	learn: 0.0351608	total: 234ms	remaining: 163ms
# 59:	learn: 0.0344223	total: 238ms	remaining: 159ms
# 60:	learn: 0.0333672	total: 242ms	remaining: 155ms
# 61:	learn: 0.0326062	total: 246ms	remaining: 151ms
# 62:	learn: 0.0316808	total: 250ms	remaining: 147ms
# 63:	learn: 0.0301995	total: 254ms	remaining: 143ms
# 64:	learn: 0.0296434	total: 258ms	remaining: 139ms
# 65:	learn: 0.0285893	total: 261ms	remaining: 135ms
# 66:	learn: 0.0279288	total: 265ms	remaining: 131ms
# 67:	learn: 0.0271953	total: 270ms	remaining: 127ms
# 68:	learn: 0.0264601	total: 274ms	remaining: 123ms
# 69:	learn: 0.0259437	total: 277ms	remaining: 119ms
# 70:	learn: 0.0252328	total: 281ms	remaining: 115ms
# 71:	learn: 0.0243768	total: 285ms	remaining: 111ms
# 72:	learn: 0.0233439	total: 290ms	remaining: 107ms
# 73:	learn: 0.0224503	total: 294ms	remaining: 103ms
# 74:	learn: 0.0218205	total: 298ms	remaining: 99.2ms
# 75:	learn: 0.0210541	total: 302ms	remaining: 95.2ms
# 76:	learn: 0.0204348	total: 306ms	remaining: 91.3ms
# 77:	learn: 0.0197202	total: 310ms	remaining: 87.3ms
# 78:	learn: 0.0192995	total: 314ms	remaining: 83.3ms
# 79:	learn: 0.0189657	total: 318ms	remaining: 79.4ms
# 80:	learn: 0.0183873	total: 321ms	remaining: 75.4ms
# 81:	learn: 0.0179149	total: 325ms	remaining: 71.4ms
# 82:	learn: 0.0175449	total: 329ms	remaining: 67.4ms
# 83:	learn: 0.0172327	total: 333ms	remaining: 63.5ms
# 84:	learn: 0.0168288	total: 337ms	remaining: 59.5ms
# 85:	learn: 0.0164332	total: 341ms	remaining: 55.5ms
# 86:	learn: 0.0159704	total: 345ms	remaining: 51.5ms
# 87:	learn: 0.0155982	total: 348ms	remaining: 47.5ms
# 88:	learn: 0.0151250	total: 352ms	remaining: 43.5ms
# 89:	learn: 0.0146133	total: 356ms	remaining: 39.6ms
# 90:	learn: 0.0143176	total: 360ms	remaining: 35.6ms
# 91:	learn: 0.0140141	total: 364ms	remaining: 31.6ms
# 92:	learn: 0.0135901	total: 368ms	remaining: 27.7ms
# 93:	learn: 0.0132964	total: 372ms	remaining: 23.7ms
# 94:	learn: 0.0130366	total: 376ms	remaining: 19.8ms
# 95:	learn: 0.0127882	total: 380ms	remaining: 15.8ms
# 96:	learn: 0.0125668	total: 384ms	remaining: 11.9ms
# 97:	learn: 0.0122828	total: 388ms	remaining: 7.91ms
# 98:	learn: 0.0121509	total: 391ms	remaining: 3.95ms
# 99:	learn: 0.0118666	total: 395ms	remaining: 0us
# 0:	learn: 0.6195639	total: 3.94ms	remaining: 390ms
# 1:	learn: 0.5602358	total: 8.12ms	remaining: 398ms
# 2:	learn: 0.5140035	total: 11.7ms	remaining: 379ms
# 3:	learn: 0.4632458	total: 15.4ms	remaining: 369ms
# 4:	learn: 0.4259355	total: 19.1ms	remaining: 363ms
# 5:	learn: 0.3919431	total: 23ms	remaining: 360ms
# 6:	learn: 0.3653464	total: 27.1ms	remaining: 360ms
# 7:	learn: 0.3327942	total: 30.7ms	remaining: 353ms
# 8:	learn: 0.3091516	total: 34.4ms	remaining: 348ms
# 9:	learn: 0.2930565	total: 38.2ms	remaining: 343ms
# 10:	learn: 0.2707286	total: 41.9ms	remaining: 339ms
# 11:	learn: 0.2564900	total: 45.6ms	remaining: 335ms
# 12:	learn: 0.2455933	total: 49.3ms	remaining: 330ms
# 13:	learn: 0.2273726	total: 53ms	remaining: 326ms
# 14:	learn: 0.2183581	total: 57ms	remaining: 323ms
# 15:	learn: 0.2106678	total: 60.7ms	remaining: 319ms
# 16:	learn: 0.1974244	total: 64.3ms	remaining: 314ms
# 17:	learn: 0.1875455	total: 68ms	remaining: 310ms
# 18:	learn: 0.1803537	total: 71.7ms	remaining: 306ms
# 19:	learn: 0.1705123	total: 75.4ms	remaining: 302ms
# 20:	learn: 0.1641511	total: 79.2ms	remaining: 298ms
# 21:	learn: 0.1560665	total: 82.9ms	remaining: 294ms
# 22:	learn: 0.1500221	total: 86.5ms	remaining: 290ms
# 23:	learn: 0.1448882	total: 90.3ms	remaining: 286ms
# 24:	learn: 0.1370332	total: 94.2ms	remaining: 283ms
# 25:	learn: 0.1305130	total: 98ms	remaining: 279ms
# 26:	learn: 0.1272796	total: 102ms	remaining: 275ms
# 27:	learn: 0.1232163	total: 105ms	remaining: 271ms
# 28:	learn: 0.1170367	total: 109ms	remaining: 267ms
# 29:	learn: 0.1132636	total: 113ms	remaining: 263ms
# 30:	learn: 0.1089655	total: 116ms	remaining: 259ms
# 31:	learn: 0.1041187	total: 120ms	remaining: 255ms
# 32:	learn: 0.1012079	total: 124ms	remaining: 251ms
# 33:	learn: 0.0973626	total: 127ms	remaining: 247ms
# 34:	learn: 0.0947526	total: 131ms	remaining: 243ms
# 35:	learn: 0.0907002	total: 134ms	remaining: 239ms
# 36:	learn: 0.0883643	total: 138ms	remaining: 235ms
# 37:	learn: 0.0857841	total: 142ms	remaining: 231ms
# 38:	learn: 0.0831556	total: 145ms	remaining: 227ms
# 39:	learn: 0.0808223	total: 149ms	remaining: 223ms
# 40:	learn: 0.0791485	total: 153ms	remaining: 220ms
# 41:	learn: 0.0773057	total: 156ms	remaining: 216ms
# 42:	learn: 0.0755375	total: 160ms	remaining: 212ms
# 43:	learn: 0.0730709	total: 163ms	remaining: 208ms
# 44:	learn: 0.0711833	total: 167ms	remaining: 204ms
# 45:	learn: 0.0698152	total: 170ms	remaining: 200ms
# 46:	learn: 0.0676262	total: 174ms	remaining: 196ms
# 47:	learn: 0.0659059	total: 177ms	remaining: 192ms
# 48:	learn: 0.0636520	total: 181ms	remaining: 188ms
# 49:	learn: 0.0620364	total: 185ms	remaining: 185ms
# 50:	learn: 0.0597700	total: 188ms	remaining: 181ms
# 51:	learn: 0.0577082	total: 192ms	remaining: 177ms
# 52:	learn: 0.0560206	total: 196ms	remaining: 174ms
# 53:	learn: 0.0549991	total: 200ms	remaining: 171ms
# 54:	learn: 0.0535112	total: 204ms	remaining: 167ms
# 55:	learn: 0.0526464	total: 208ms	remaining: 163ms
# 56:	learn: 0.0510149	total: 214ms	remaining: 161ms
# 57:	learn: 0.0496101	total: 218ms	remaining: 158ms
# 58:	learn: 0.0480758	total: 221ms	remaining: 154ms
# 59:	learn: 0.0466633	total: 225ms	remaining: 150ms
# 60:	learn: 0.0449424	total: 229ms	remaining: 146ms
# 61:	learn: 0.0440443	total: 232ms	remaining: 142ms
# 62:	learn: 0.0431573	total: 236ms	remaining: 139ms
# 63:	learn: 0.0415643	total: 240ms	remaining: 135ms
# 64:	learn: 0.0398321	total: 243ms	remaining: 131ms
# 65:	learn: 0.0388728	total: 247ms	remaining: 127ms
# 66:	learn: 0.0377564	total: 252ms	remaining: 124ms
# 67:	learn: 0.0367001	total: 256ms	remaining: 120ms
# 68:	learn: 0.0356959	total: 260ms	remaining: 117ms
# 69:	learn: 0.0350130	total: 263ms	remaining: 113ms
# 70:	learn: 0.0344771	total: 267ms	remaining: 109ms
# 71:	learn: 0.0333762	total: 270ms	remaining: 105ms
# 72:	learn: 0.0328053	total: 274ms	remaining: 101ms
# 73:	learn: 0.0327496	total: 277ms	remaining: 97.4ms
# 74:	learn: 0.0316422	total: 281ms	remaining: 93.6ms
# 75:	learn: 0.0311103	total: 285ms	remaining: 89.9ms
# 76:	learn: 0.0304642	total: 288ms	remaining: 86.1ms
# 77:	learn: 0.0296353	total: 292ms	remaining: 82.3ms
# 78:	learn: 0.0288259	total: 295ms	remaining: 78.5ms
# 79:	learn: 0.0282606	total: 299ms	remaining: 74.8ms
# 80:	learn: 0.0273838	total: 303ms	remaining: 71ms
# 81:	learn: 0.0267717	total: 306ms	remaining: 67.2ms
# 82:	learn: 0.0264667	total: 310ms	remaining: 63.4ms
# 83:	learn: 0.0256264	total: 313ms	remaining: 59.7ms
# 84:	learn: 0.0250384	total: 317ms	remaining: 55.9ms
# 85:	learn: 0.0244605	total: 320ms	remaining: 52.2ms
# 86:	learn: 0.0238932	total: 324ms	remaining: 48.5ms
# 87:	learn: 0.0235405	total: 328ms	remaining: 44.7ms
# 88:	learn: 0.0231819	total: 332ms	remaining: 41ms
# 89:	learn: 0.0223298	total: 335ms	remaining: 37.3ms
# 90:	learn: 0.0215356	total: 339ms	remaining: 33.5ms
# 91:	learn: 0.0208251	total: 343ms	remaining: 29.8ms
# 92:	learn: 0.0201898	total: 347ms	remaining: 26.1ms
# 93:	learn: 0.0199473	total: 350ms	remaining: 22.4ms
# 94:	learn: 0.0194005	total: 354ms	remaining: 18.6ms
# 95:	learn: 0.0190879	total: 357ms	remaining: 14.9ms
# 96:	learn: 0.0185673	total: 362ms	remaining: 11.2ms
# 97:	learn: 0.0182446	total: 366ms	remaining: 7.47ms
# 98:	learn: 0.0177785	total: 369ms	remaining: 3.73ms
# 99:	learn: 0.0173895	total: 373ms	remaining: 0us
# 0:	learn: 0.6113317	total: 4.23ms	remaining: 419ms
# 1:	learn: 0.5451968	total: 8.34ms	remaining: 409ms
# 2:	learn: 0.4992145	total: 12.5ms	remaining: 405ms
# 3:	learn: 0.4678032	total: 16.4ms	remaining: 393ms
# 4:	learn: 0.4351782	total: 20.1ms	remaining: 381ms
# 5:	learn: 0.4049567	total: 23.8ms	remaining: 373ms
# 6:	learn: 0.3630946	total: 27.6ms	remaining: 367ms
# 7:	learn: 0.3423047	total: 31.4ms	remaining: 362ms
# 8:	learn: 0.3156750	total: 35ms	remaining: 354ms
# 9:	learn: 0.2961923	total: 38.6ms	remaining: 348ms
# 10:	learn: 0.2778498	total: 42.2ms	remaining: 342ms
# 11:	learn: 0.2659700	total: 46ms	remaining: 338ms
# 12:	learn: 0.2520708	total: 50.2ms	remaining: 336ms
# 13:	learn: 0.2376019	total: 54ms	remaining: 332ms
# 14:	learn: 0.2299263	total: 57.8ms	remaining: 328ms
# 15:	learn: 0.2185921	total: 61.5ms	remaining: 323ms
# 16:	learn: 0.2149170	total: 65.3ms	remaining: 319ms
# 17:	learn: 0.2039469	total: 69ms	remaining: 314ms
# 18:	learn: 0.1934750	total: 72.8ms	remaining: 310ms
# 19:	learn: 0.1849575	total: 76.6ms	remaining: 307ms
# 20:	learn: 0.1781866	total: 80.3ms	remaining: 302ms
# 21:	learn: 0.1699449	total: 84.1ms	remaining: 298ms
# 22:	learn: 0.1618886	total: 87.7ms	remaining: 294ms
# 23:	learn: 0.1553318	total: 91.6ms	remaining: 290ms
# 24:	learn: 0.1506273	total: 95.4ms	remaining: 286ms
# 25:	learn: 0.1459455	total: 99.2ms	remaining: 282ms
# 26:	learn: 0.1396435	total: 103ms	remaining: 278ms
# 27:	learn: 0.1320588	total: 107ms	remaining: 275ms
# 28:	learn: 0.1264122	total: 111ms	remaining: 271ms
# 29:	learn: 0.1180227	total: 114ms	remaining: 266ms
# 30:	learn: 0.1131279	total: 118ms	remaining: 263ms
# 31:	learn: 0.1090429	total: 122ms	remaining: 259ms
# 32:	learn: 0.1050434	total: 126ms	remaining: 255ms
# 33:	learn: 0.1008335	total: 129ms	remaining: 251ms
# 34:	learn: 0.0976645	total: 133ms	remaining: 247ms
# 35:	learn: 0.0938719	total: 137ms	remaining: 243ms
# 36:	learn: 0.0897061	total: 141ms	remaining: 239ms
# 37:	learn: 0.0871839	total: 145ms	remaining: 236ms
# 38:	learn: 0.0839903	total: 149ms	remaining: 232ms
# 39:	learn: 0.0817990	total: 152ms	remaining: 229ms
# 40:	learn: 0.0795629	total: 158ms	remaining: 227ms
# 41:	learn: 0.0770573	total: 162ms	remaining: 223ms
# 42:	learn: 0.0744341	total: 166ms	remaining: 220ms
# 43:	learn: 0.0717779	total: 169ms	remaining: 216ms
# 44:	learn: 0.0695818	total: 173ms	remaining: 211ms
# 45:	learn: 0.0672900	total: 177ms	remaining: 208ms
# 46:	learn: 0.0652777	total: 181ms	remaining: 204ms
# 47:	learn: 0.0628839	total: 184ms	remaining: 200ms
# 48:	learn: 0.0614720	total: 188ms	remaining: 196ms
# 49:	learn: 0.0600928	total: 192ms	remaining: 192ms
# 50:	learn: 0.0581588	total: 196ms	remaining: 188ms
# 51:	learn: 0.0560856	total: 201ms	remaining: 186ms
# 52:	learn: 0.0537283	total: 205ms	remaining: 182ms
# 53:	learn: 0.0524681	total: 209ms	remaining: 178ms
# 54:	learn: 0.0511019	total: 213ms	remaining: 174ms
# 55:	learn: 0.0498481	total: 217ms	remaining: 170ms
# 56:	learn: 0.0488189	total: 221ms	remaining: 167ms
# 57:	learn: 0.0472430	total: 224ms	remaining: 163ms
# 58:	learn: 0.0458466	total: 228ms	remaining: 159ms
# 59:	learn: 0.0447642	total: 232ms	remaining: 155ms
# 60:	learn: 0.0438583	total: 236ms	remaining: 151ms
# 61:	learn: 0.0424699	total: 239ms	remaining: 147ms
# 62:	learn: 0.0412021	total: 243ms	remaining: 143ms
# 63:	learn: 0.0396827	total: 247ms	remaining: 139ms
# 64:	learn: 0.0384413	total: 251ms	remaining: 135ms
# 65:	learn: 0.0373842	total: 255ms	remaining: 131ms
# 66:	learn: 0.0362972	total: 259ms	remaining: 128ms
# 67:	learn: 0.0350682	total: 263ms	remaining: 124ms
# 68:	learn: 0.0339405	total: 267ms	remaining: 120ms
# 69:	learn: 0.0329620	total: 271ms	remaining: 116ms
# 70:	learn: 0.0317561	total: 275ms	remaining: 112ms
# 71:	learn: 0.0309881	total: 278ms	remaining: 108ms
# 72:	learn: 0.0302335	total: 282ms	remaining: 104ms
# 73:	learn: 0.0294874	total: 286ms	remaining: 101ms
# 74:	learn: 0.0285321	total: 290ms	remaining: 96.6ms
# 75:	learn: 0.0275902	total: 294ms	remaining: 92.7ms
# 76:	learn: 0.0268956	total: 297ms	remaining: 88.8ms
# 77:	learn: 0.0262756	total: 301ms	remaining: 85ms
# 78:	learn: 0.0256318	total: 305ms	remaining: 81.1ms
# 79:	learn: 0.0248384	total: 309ms	remaining: 77.2ms
# 80:	learn: 0.0242867	total: 312ms	remaining: 73.3ms
# 81:	learn: 0.0237320	total: 316ms	remaining: 69.4ms
# 82:	learn: 0.0231089	total: 320ms	remaining: 65.6ms
# 83:	learn: 0.0225715	total: 324ms	remaining: 61.7ms
# 84:	learn: 0.0219854	total: 328ms	remaining: 57.8ms
# 85:	learn: 0.0214383	total: 331ms	remaining: 53.9ms
# 86:	learn: 0.0210073	total: 335ms	remaining: 50.1ms
# 87:	learn: 0.0206366	total: 339ms	remaining: 46.2ms
# 88:	learn: 0.0202465	total: 343ms	remaining: 42.4ms
# 89:	learn: 0.0198497	total: 346ms	remaining: 38.5ms
# 90:	learn: 0.0192996	total: 350ms	remaining: 34.6ms
# 91:	learn: 0.0186979	total: 354ms	remaining: 30.8ms
# 92:	learn: 0.0184134	total: 358ms	remaining: 26.9ms
# 93:	learn: 0.0180667	total: 362ms	remaining: 23.1ms
# 94:	learn: 0.0176889	total: 365ms	remaining: 19.2ms
# 95:	learn: 0.0173281	total: 369ms	remaining: 15.4ms
# 96:	learn: 0.0169981	total: 373ms	remaining: 11.5ms
# 97:	learn: 0.0167382	total: 377ms	remaining: 7.68ms
# 98:	learn: 0.0164446	total: 380ms	remaining: 3.84ms
# 99:	learn: 0.0161029	total: 384ms	remaining: 0us
# 0:	learn: 0.6126460	total: 3.49ms	remaining: 346ms
# 1:	learn: 0.5244724	total: 7.41ms	remaining: 363ms
# 2:	learn: 0.4545091	total: 10.8ms	remaining: 350ms
# 3:	learn: 0.4089065	total: 14.2ms	remaining: 341ms
# 4:	learn: 0.3731084	total: 17.6ms	remaining: 335ms
# 5:	learn: 0.3428547	total: 21.1ms	remaining: 331ms
# 6:	learn: 0.3212681	total: 24.6ms	remaining: 327ms
# 7:	learn: 0.2971963	total: 28.5ms	remaining: 328ms
# 8:	learn: 0.2809144	total: 32.3ms	remaining: 326ms
# 9:	learn: 0.2591699	total: 35.8ms	remaining: 322ms
# 10:	learn: 0.2446402	total: 39.2ms	remaining: 317ms
# 11:	learn: 0.2325853	total: 42.6ms	remaining: 312ms
# 12:	learn: 0.2148400	total: 46.1ms	remaining: 308ms
# 13:	learn: 0.2015507	total: 49.4ms	remaining: 304ms
# 14:	learn: 0.1877364	total: 52.9ms	remaining: 300ms
# 15:	learn: 0.1801471	total: 56.2ms	remaining: 295ms
# 16:	learn: 0.1711537	total: 59.8ms	remaining: 292ms
# 17:	learn: 0.1634432	total: 63.5ms	remaining: 289ms
# 18:	learn: 0.1538787	total: 66.9ms	remaining: 285ms
# 19:	learn: 0.1477196	total: 70.3ms	remaining: 281ms
# 20:	learn: 0.1425547	total: 73.7ms	remaining: 277ms
# 21:	learn: 0.1387722	total: 77.2ms	remaining: 274ms
# 22:	learn: 0.1332472	total: 80.6ms	remaining: 270ms
# 23:	learn: 0.1290111	total: 84.1ms	remaining: 266ms
# 24:	learn: 0.1224100	total: 87.8ms	remaining: 263ms
# 25:	learn: 0.1170761	total: 91.1ms	remaining: 259ms
# 26:	learn: 0.1126831	total: 94.4ms	remaining: 255ms
# 27:	learn: 0.1080345	total: 97.7ms	remaining: 251ms
# 28:	learn: 0.1042519	total: 101ms	remaining: 247ms
# 29:	learn: 0.0984925	total: 105ms	remaining: 244ms
# 30:	learn: 0.0946973	total: 108ms	remaining: 240ms
# 31:	learn: 0.0906054	total: 111ms	remaining: 237ms
# 32:	learn: 0.0890013	total: 115ms	remaining: 233ms
# 33:	learn: 0.0853385	total: 118ms	remaining: 229ms
# 34:	learn: 0.0823503	total: 122ms	remaining: 226ms
# 35:	learn: 0.0794206	total: 126ms	remaining: 223ms
# 36:	learn: 0.0755299	total: 129ms	remaining: 220ms
# 37:	learn: 0.0734756	total: 133ms	remaining: 216ms
# 38:	learn: 0.0710554	total: 136ms	remaining: 213ms
# 39:	learn: 0.0691548	total: 139ms	remaining: 209ms
# 40:	learn: 0.0672546	total: 143ms	remaining: 206ms
# 41:	learn: 0.0643711	total: 147ms	remaining: 202ms
# 42:	learn: 0.0631933	total: 150ms	remaining: 199ms
# 43:	learn: 0.0609033	total: 154ms	remaining: 196ms
# 44:	learn: 0.0584944	total: 158ms	remaining: 193ms
# 45:	learn: 0.0570291	total: 161ms	remaining: 189ms
# 46:	learn: 0.0551788	total: 165ms	remaining: 186ms
# 47:	learn: 0.0535470	total: 168ms	remaining: 182ms
# 48:	learn: 0.0523068	total: 172ms	remaining: 179ms
# 49:	learn: 0.0511503	total: 175ms	remaining: 175ms
# 50:	learn: 0.0500037	total: 179ms	remaining: 172ms
# 51:	learn: 0.0488615	total: 182ms	remaining: 168ms
# 52:	learn: 0.0475106	total: 185ms	remaining: 164ms
# 53:	learn: 0.0458534	total: 189ms	remaining: 161ms
# 54:	learn: 0.0441551	total: 192ms	remaining: 157ms
# 55:	learn: 0.0435547	total: 196ms	remaining: 154ms
# 56:	learn: 0.0418623	total: 201ms	remaining: 152ms
# 57:	learn: 0.0408607	total: 205ms	remaining: 148ms
# 58:	learn: 0.0399847	total: 208ms	remaining: 145ms
# 59:	learn: 0.0390685	total: 212ms	remaining: 141ms
# 60:	learn: 0.0377973	total: 215ms	remaining: 137ms
# 61:	learn: 0.0362455	total: 218ms	remaining: 134ms
# 62:	learn: 0.0353019	total: 222ms	remaining: 131ms
# 63:	learn: 0.0339005	total: 226ms	remaining: 127ms
# 64:	learn: 0.0329839	total: 229ms	remaining: 123ms
# 65:	learn: 0.0324660	total: 233ms	remaining: 120ms
# 66:	learn: 0.0314371	total: 236ms	remaining: 116ms
# 67:	learn: 0.0305221	total: 240ms	remaining: 113ms
# 68:	learn: 0.0296566	total: 243ms	remaining: 109ms
# 69:	learn: 0.0288106	total: 247ms	remaining: 106ms
# 70:	learn: 0.0277717	total: 251ms	remaining: 102ms
# 71:	learn: 0.0270462	total: 254ms	remaining: 98.8ms
# 72:	learn: 0.0260266	total: 258ms	remaining: 95.4ms
# 73:	learn: 0.0249865	total: 262ms	remaining: 91.9ms
# 74:	learn: 0.0242758	total: 265ms	remaining: 88.4ms
# 75:	learn: 0.0237274	total: 269ms	remaining: 84.8ms
# 76:	learn: 0.0234029	total: 272ms	remaining: 81.3ms
# 77:	learn: 0.0230409	total: 276ms	remaining: 77.8ms
# 78:	learn: 0.0222556	total: 279ms	remaining: 74.3ms
# 79:	learn: 0.0218619	total: 283ms	remaining: 70.7ms
# 80:	learn: 0.0211982	total: 286ms	remaining: 67.2ms
# 81:	learn: 0.0206748	total: 290ms	remaining: 63.6ms
# 82:	learn: 0.0200172	total: 293ms	remaining: 60.1ms
# 83:	learn: 0.0199494	total: 297ms	remaining: 56.5ms
# 84:	learn: 0.0193800	total: 300ms	remaining: 53ms
# 85:	learn: 0.0187619	total: 304ms	remaining: 49.4ms
# 86:	learn: 0.0181902	total: 307ms	remaining: 45.9ms
# 87:	learn: 0.0177617	total: 310ms	remaining: 42.3ms
# 88:	learn: 0.0173477	total: 314ms	remaining: 38.8ms
# 89:	learn: 0.0168245	total: 318ms	remaining: 35.3ms
# 90:	learn: 0.0165237	total: 321ms	remaining: 31.8ms
# 91:	learn: 0.0164937	total: 325ms	remaining: 28.2ms
# 92:	learn: 0.0161238	total: 328ms	remaining: 24.7ms
# 93:	learn: 0.0158088	total: 332ms	remaining: 21.2ms
# 94:	learn: 0.0157771	total: 335ms	remaining: 17.6ms
# 95:	learn: 0.0153815	total: 339ms	remaining: 14.1ms
# 96:	learn: 0.0150200	total: 343ms	remaining: 10.6ms
# 97:	learn: 0.0146443	total: 346ms	remaining: 7.06ms
# 98:	learn: 0.0142136	total: 350ms	remaining: 3.53ms
# 99:	learn: 0.0138791	total: 353ms	remaining: 0us
# 0:	learn: 0.6410267	total: 4.11ms	remaining: 407ms
# 1:	learn: 0.5813152	total: 7.86ms	remaining: 385ms
# 2:	learn: 0.5223932	total: 11.6ms	remaining: 377ms
# 3:	learn: 0.4826359	total: 16.7ms	remaining: 402ms
# 4:	learn: 0.4539121	total: 20.8ms	remaining: 395ms
# 5:	learn: 0.4259437	total: 24.5ms	remaining: 384ms
# 6:	learn: 0.3930626	total: 28.4ms	remaining: 378ms
# 7:	learn: 0.3671214	total: 32.3ms	remaining: 371ms
# 8:	learn: 0.3448721	total: 36.4ms	remaining: 368ms
# 9:	learn: 0.3273224	total: 40.2ms	remaining: 362ms
# 10:	learn: 0.3137157	total: 44.3ms	remaining: 359ms
# 11:	learn: 0.2955889	total: 48.4ms	remaining: 355ms
# 12:	learn: 0.2773124	total: 52.4ms	remaining: 350ms
# 13:	learn: 0.2644290	total: 56.3ms	remaining: 346ms
# 14:	learn: 0.2552795	total: 60.1ms	remaining: 340ms
# 15:	learn: 0.2428683	total: 64.1ms	remaining: 337ms
# 16:	learn: 0.2347296	total: 68.1ms	remaining: 332ms
# 17:	learn: 0.2204208	total: 72ms	remaining: 328ms
# 18:	learn: 0.2095537	total: 75.7ms	remaining: 323ms
# 19:	learn: 0.2019155	total: 79.6ms	remaining: 318ms
# 20:	learn: 0.1933850	total: 83.9ms	remaining: 316ms
# 21:	learn: 0.1834854	total: 87.6ms	remaining: 310ms
# 22:	learn: 0.1741577	total: 91.3ms	remaining: 306ms
# 23:	learn: 0.1696169	total: 95.2ms	remaining: 301ms
# 24:	learn: 0.1642210	total: 99ms	remaining: 297ms
# 25:	learn: 0.1597063	total: 103ms	remaining: 293ms
# 26:	learn: 0.1534145	total: 107ms	remaining: 288ms
# 27:	learn: 0.1451337	total: 110ms	remaining: 284ms
# 28:	learn: 0.1396482	total: 114ms	remaining: 280ms
# 29:	learn: 0.1337467	total: 118ms	remaining: 275ms
# 30:	learn: 0.1292349	total: 122ms	remaining: 271ms
# 31:	learn: 0.1219330	total: 126ms	remaining: 267ms
# ...
# 90:	learn: 0.0174618	total: 309ms	remaining: 30.6ms
# 91:	learn: 0.0170059	total: 312ms	remaining: 27.2ms
# 92:	learn: 0.0166408	total: 316ms	remaining: 23.8ms
# 93:	learn: 0.0163557	total: 320ms	remaining: 20.4ms
# 94:	learn: 0.0159196	total: 323ms	remaining: 17ms
# 95:	learn: 0.0156807	total: 327ms	remaining: 13.6ms
# 96:	learn: 0.0153851	total: 330ms	remaining: 10.2ms
# 97:	learn: 0.0151708	total: 333ms	remaining: 6.8ms
# 98:	learn: 0.0149086	total: 337ms	remaining: 3.4ms
# 99:	learn: 0.0147813	total: 340ms	remaining: 0us
# 0:	learn: 0.5923174	total: 3.77ms	remaining: 374ms
# 1:	learn: 0.5417383	total: 7.33ms	remaining: 359ms
# 2:	learn: 0.4827606	total: 11.1ms	remaining: 357ms
# 3:	learn: 0.4420193	total: 14.7ms	remaining: 352ms
# 4:	learn: 0.3955378	total: 18.3ms	remaining: 347ms
# 5:	learn: 0.3619208	total: 21.9ms	remaining: 343ms
# 6:	learn: 0.3406296	total: 26.3ms	remaining: 349ms
# 7:	learn: 0.3142016	total: 30.9ms	remaining: 355ms
# 8:	learn: 0.2909840	total: 34.4ms	remaining: 348ms
# 9:	learn: 0.2704594	total: 37.9ms	remaining: 341ms
# 10:	learn: 0.2550327	total: 41.4ms	remaining: 335ms
# 11:	learn: 0.2381861	total: 44.9ms	remaining: 329ms
# 12:	learn: 0.2229160	total: 48.4ms	remaining: 324ms
# 13:	learn: 0.2069298	total: 51.8ms	remaining: 318ms
# 14:	learn: 0.1915007	total: 55.4ms	remaining: 314ms
# 15:	learn: 0.1856146	total: 59ms	remaining: 310ms
# 16:	learn: 0.1763664	total: 63.2ms	remaining: 309ms
# 17:	learn: 0.1623137	total: 67.3ms	remaining: 307ms
# 18:	learn: 0.1518412	total: 71ms	remaining: 302ms
# 19:	learn: 0.1427574	total: 76.2ms	remaining: 305ms
# 20:	learn: 0.1364836	total: 80ms	remaining: 301ms
# 21:	learn: 0.1290515	total: 84ms	remaining: 298ms
# 22:	learn: 0.1222352	total: 87.7ms	remaining: 294ms
# 23:	learn: 0.1169816	total: 91.3ms	remaining: 289ms
# 24:	learn: 0.1086292	total: 94.9ms	remaining: 285ms
# 25:	learn: 0.1037176	total: 98.4ms	remaining: 280ms
# 26:	learn: 0.0991960	total: 102ms	remaining: 276ms
# 27:	learn: 0.0955151	total: 106ms	remaining: 272ms
# 28:	learn: 0.0928772	total: 109ms	remaining: 268ms
# 29:	learn: 0.0887783	total: 113ms	remaining: 263ms
# 30:	learn: 0.0855316	total: 116ms	remaining: 259ms
# 31:	learn: 0.0814345	total: 120ms	remaining: 255ms
# 32:	learn: 0.0771543	total: 123ms	remaining: 251ms
# 33:	learn: 0.0729598	total: 127ms	remaining: 247ms
# 34:	learn: 0.0698313	total: 130ms	remaining: 242ms
# 35:	learn: 0.0673487	total: 134ms	remaining: 238ms
# 36:	learn: 0.0656999	total: 138ms	remaining: 234ms
# 37:	learn: 0.0631946	total: 141ms	remaining: 230ms
# 38:	learn: 0.0597190	total: 145ms	remaining: 226ms
# 39:	learn: 0.0577491	total: 148ms	remaining: 223ms
# 40:	learn: 0.0551445	total: 152ms	remaining: 219ms
# 41:	learn: 0.0530859	total: 156ms	remaining: 215ms
# 42:	learn: 0.0512735	total: 159ms	remaining: 211ms
# 43:	learn: 0.0494836	total: 163ms	remaining: 207ms
# 44:	learn: 0.0486083	total: 166ms	remaining: 203ms
# 45:	learn: 0.0470456	total: 170ms	remaining: 199ms
# 46:	learn: 0.0454249	total: 173ms	remaining: 195ms
# 47:	learn: 0.0436419	total: 177ms	remaining: 192ms
# 48:	learn: 0.0420494	total: 181ms	remaining: 188ms
# 49:	learn: 0.0406673	total: 184ms	remaining: 184ms
# 50:	learn: 0.0396551	total: 188ms	remaining: 181ms
# 51:	learn: 0.0381122	total: 191ms	remaining: 177ms
# 52:	learn: 0.0370568	total: 195ms	remaining: 173ms
# 53:	learn: 0.0361953	total: 198ms	remaining: 169ms
# 54:	learn: 0.0356584	total: 202ms	remaining: 165ms
# 55:	learn: 0.0344063	total: 206ms	remaining: 162ms
# 56:	learn: 0.0331316	total: 209ms	remaining: 158ms
# 57:	learn: 0.0322998	total: 212ms	remaining: 154ms
# 58:	learn: 0.0314147	total: 216ms	remaining: 150ms
# 59:	learn: 0.0307329	total: 221ms	remaining: 147ms
# 60:	learn: 0.0299491	total: 225ms	remaining: 144ms
# 61:	learn: 0.0289857	total: 228ms	remaining: 140ms
# 62:	learn: 0.0280414	total: 232ms	remaining: 136ms
# 63:	learn: 0.0272371	total: 235ms	remaining: 132ms
# 64:	learn: 0.0265378	total: 239ms	remaining: 129ms
# 65:	learn: 0.0258054	total: 242ms	remaining: 125ms
# 66:	learn: 0.0250695	total: 246ms	remaining: 121ms
# 67:	learn: 0.0242232	total: 250ms	remaining: 117ms
# 68:	learn: 0.0234579	total: 253ms	remaining: 114ms
# 69:	learn: 0.0226103	total: 257ms	remaining: 110ms
# 70:	learn: 0.0219317	total: 260ms	remaining: 106ms
# 71:	learn: 0.0214342	total: 264ms	remaining: 103ms
# 72:	learn: 0.0208806	total: 268ms	remaining: 99ms
# 73:	learn: 0.0203946	total: 271ms	remaining: 95.3ms
# 74:	learn: 0.0199913	total: 275ms	remaining: 91.6ms
# 75:	learn: 0.0191914	total: 278ms	remaining: 87.9ms
# 76:	learn: 0.0188692	total: 282ms	remaining: 84.2ms
# 77:	learn: 0.0182336	total: 285ms	remaining: 80.5ms
# 78:	learn: 0.0177967	total: 289ms	remaining: 76.8ms
# 79:	learn: 0.0173291	total: 292ms	remaining: 73.1ms
# 80:	learn: 0.0169839	total: 296ms	remaining: 69.4ms
# 81:	learn: 0.0167111	total: 299ms	remaining: 65.6ms
# 82:	learn: 0.0162517	total: 303ms	remaining: 62ms
# 83:	learn: 0.0160004	total: 306ms	remaining: 58.3ms
# 84:	learn: 0.0155818	total: 310ms	remaining: 54.6ms
# 85:	learn: 0.0151486	total: 313ms	remaining: 51ms
# 86:	learn: 0.0147490	total: 317ms	remaining: 47.4ms
# 87:	learn: 0.0143416	total: 321ms	remaining: 43.7ms
# 88:	learn: 0.0139159	total: 324ms	remaining: 40.1ms
# 89:	learn: 0.0138726	total: 328ms	remaining: 36.4ms
# 90:	learn: 0.0134835	total: 331ms	remaining: 32.8ms
# 91:	learn: 0.0132338	total: 335ms	remaining: 29.1ms
# 92:	learn: 0.0129500	total: 338ms	remaining: 25.5ms
# 93:	learn: 0.0126373	total: 342ms	remaining: 21.8ms
# 94:	learn: 0.0124294	total: 345ms	remaining: 18.2ms
# 95:	learn: 0.0121868	total: 349ms	remaining: 14.5ms
# 96:	learn: 0.0119557	total: 353ms	remaining: 10.9ms
# 97:	learn: 0.0118421	total: 356ms	remaining: 7.27ms
# 98:	learn: 0.0116402	total: 360ms	remaining: 3.63ms
# 99:	learn: 0.0114451	total: 363ms	remaining: 0us
# 0:	learn: 0.6152297	total: 3.98ms	remaining: 394ms
# 1:	learn: 0.5568743	total: 8.03ms	remaining: 393ms
# 2:	learn: 0.5123051	total: 11.9ms	remaining: 385ms
# 3:	learn: 0.4485234	total: 15.8ms	remaining: 380ms
# 4:	learn: 0.4181853	total: 19.8ms	remaining: 376ms
# 5:	learn: 0.3814602	total: 24.2ms	remaining: 380ms
# 6:	learn: 0.3382067	total: 29.1ms	remaining: 387ms
# 7:	learn: 0.3178871	total: 32.8ms	remaining: 378ms
# 8:	learn: 0.2997118	total: 36.5ms	remaining: 369ms
# 9:	learn: 0.2816567	total: 40.3ms	remaining: 363ms
# 10:	learn: 0.2526601	total: 44.1ms	remaining: 357ms
# 11:	learn: 0.2374362	total: 47.9ms	remaining: 351ms
# 12:	learn: 0.2202602	total: 51.6ms	remaining: 346ms
# 13:	learn: 0.2076820	total: 55.4ms	remaining: 340ms
# 14:	learn: 0.1924210	total: 59.2ms	remaining: 336ms
# 15:	learn: 0.1780918	total: 62.9ms	remaining: 330ms
# 16:	learn: 0.1683902	total: 66.6ms	remaining: 325ms
# 17:	learn: 0.1614117	total: 70.3ms	remaining: 320ms
# 18:	learn: 0.1535679	total: 74.1ms	remaining: 316ms
# 19:	learn: 0.1465562	total: 78ms	remaining: 312ms
# 20:	learn: 0.1392837	total: 81.8ms	remaining: 308ms
# 21:	learn: 0.1358613	total: 85.5ms	remaining: 303ms
# 22:	learn: 0.1302152	total: 89.3ms	remaining: 299ms
# 23:	learn: 0.1258314	total: 93ms	remaining: 295ms
# 24:	learn: 0.1214264	total: 96.8ms	remaining: 290ms
# 25:	learn: 0.1161772	total: 101ms	remaining: 286ms
# 26:	learn: 0.1118224	total: 104ms	remaining: 282ms
# 27:	learn: 0.1082076	total: 108ms	remaining: 277ms
# 28:	learn: 0.1031909	total: 111ms	remaining: 273ms
# 29:	learn: 0.1000650	total: 115ms	remaining: 268ms
# 30:	learn: 0.0951613	total: 119ms	remaining: 264ms
# 31:	learn: 0.0920727	total: 122ms	remaining: 260ms
# 32:	learn: 0.0884522	total: 126ms	remaining: 256ms
# 33:	learn: 0.0833758	total: 130ms	remaining: 252ms
# 34:	learn: 0.0783758	total: 133ms	remaining: 247ms
# 35:	learn: 0.0751059	total: 137ms	remaining: 243ms
# 36:	learn: 0.0720606	total: 140ms	remaining: 239ms
# 37:	learn: 0.0698128	total: 144ms	remaining: 235ms
# 38:	learn: 0.0670186	total: 148ms	remaining: 231ms
# 39:	learn: 0.0647689	total: 151ms	remaining: 227ms
# 40:	learn: 0.0617402	total: 155ms	remaining: 223ms
# 41:	learn: 0.0589273	total: 158ms	remaining: 219ms
# 42:	learn: 0.0567934	total: 162ms	remaining: 215ms
# 43:	learn: 0.0547977	total: 166ms	remaining: 211ms
# 44:	learn: 0.0525486	total: 169ms	remaining: 207ms
# 45:	learn: 0.0509351	total: 173ms	remaining: 203ms
# 46:	learn: 0.0491635	total: 176ms	remaining: 199ms
# 47:	learn: 0.0476325	total: 181ms	remaining: 196ms
# 48:	learn: 0.0458178	total: 184ms	remaining: 192ms
# 49:	learn: 0.0440551	total: 188ms	remaining: 188ms
# 50:	learn: 0.0421788	total: 191ms	remaining: 184ms
# 51:	learn: 0.0402122	total: 195ms	remaining: 180ms
# 52:	learn: 0.0391647	total: 198ms	remaining: 176ms
# 53:	learn: 0.0378554	total: 202ms	remaining: 172ms
# 54:	learn: 0.0369888	total: 205ms	remaining: 168ms
# 55:	learn: 0.0356401	total: 209ms	remaining: 164ms
# 56:	learn: 0.0347671	total: 212ms	remaining: 160ms
# 57:	learn: 0.0339503	total: 217ms	remaining: 157ms
# 58:	learn: 0.0326269	total: 221ms	remaining: 154ms
# 59:	learn: 0.0319559	total: 225ms	remaining: 150ms
# 60:	learn: 0.0311157	total: 229ms	remaining: 146ms
# 61:	learn: 0.0303027	total: 232ms	remaining: 142ms
# 62:	learn: 0.0295268	total: 236ms	remaining: 139ms
# 63:	learn: 0.0283725	total: 240ms	remaining: 135ms
# 64:	learn: 0.0274161	total: 243ms	remaining: 131ms
# 65:	learn: 0.0266063	total: 247ms	remaining: 127ms
# 66:	learn: 0.0258577	total: 251ms	remaining: 123ms
# 67:	learn: 0.0248829	total: 254ms	remaining: 120ms
# 68:	learn: 0.0241142	total: 258ms	remaining: 116ms
# 69:	learn: 0.0234491	total: 261ms	remaining: 112ms
# 70:	learn: 0.0227419	total: 265ms	remaining: 108ms
# 71:	learn: 0.0220541	total: 269ms	remaining: 105ms
# 72:	learn: 0.0213455	total: 272ms	remaining: 101ms
# 73:	learn: 0.0206029	total: 276ms	remaining: 97.1ms
# 74:	learn: 0.0202049	total: 280ms	remaining: 93.4ms
# 75:	learn: 0.0193752	total: 284ms	remaining: 89.6ms
# 76:	learn: 0.0188305	total: 287ms	remaining: 85.9ms
# 77:	learn: 0.0183496	total: 291ms	remaining: 82.1ms
# 78:	learn: 0.0179596	total: 295ms	remaining: 78.4ms
# 79:	learn: 0.0175577	total: 299ms	remaining: 74.6ms
# 80:	learn: 0.0169651	total: 302ms	remaining: 70.9ms
# 81:	learn: 0.0165637	total: 306ms	remaining: 67.1ms
# 82:	learn: 0.0162520	total: 309ms	remaining: 63.4ms
# 83:	learn: 0.0158183	total: 313ms	remaining: 59.6ms
# 84:	learn: 0.0154326	total: 317ms	remaining: 55.9ms
# 85:	learn: 0.0149702	total: 320ms	remaining: 52.2ms
# 86:	learn: 0.0146023	total: 324ms	remaining: 48.4ms
# 87:	learn: 0.0142832	total: 328ms	remaining: 44.7ms
# 88:	learn: 0.0139863	total: 331ms	remaining: 40.9ms
# 89:	learn: 0.0136840	total: 335ms	remaining: 37.2ms
# 90:	learn: 0.0133153	total: 338ms	remaining: 33.5ms
# 91:	learn: 0.0130926	total: 342ms	remaining: 29.8ms
# 92:	learn: 0.0128538	total: 346ms	remaining: 26ms
# 93:	learn: 0.0125835	total: 350ms	remaining: 22.3ms
# 94:	learn: 0.0124412	total: 353ms	remaining: 18.6ms
# 95:	learn: 0.0122819	total: 357ms	remaining: 14.9ms
# 96:	learn: 0.0120492	total: 361ms	remaining: 11.2ms
# 97:	learn: 0.0118367	total: 364ms	remaining: 7.43ms
# 98:	learn: 0.0116089	total: 368ms	remaining: 3.71ms
# 99:	learn: 0.0114342	total: 371ms	remaining: 0us
# 0:	learn: 0.6258044	total: 4ms	remaining: 396ms
# 1:	learn: 0.5743461	total: 7.57ms	remaining: 371ms
# 2:	learn: 0.5236837	total: 11.3ms	remaining: 365ms
# 3:	learn: 0.4654549	total: 16.3ms	remaining: 391ms
# 4:	learn: 0.4351153	total: 20.6ms	remaining: 391ms
# 5:	learn: 0.3993720	total: 24.8ms	remaining: 388ms
# 6:	learn: 0.3698446	total: 28.8ms	remaining: 383ms
# 7:	learn: 0.3409490	total: 32.7ms	remaining: 376ms
# 8:	learn: 0.3192204	total: 36.4ms	remaining: 368ms
# 9:	learn: 0.2949414	total: 40.1ms	remaining: 360ms
# 10:	learn: 0.2759225	total: 43.8ms	remaining: 354ms
# 11:	learn: 0.2546046	total: 47.5ms	remaining: 348ms
# 12:	learn: 0.2405642	total: 51.3ms	remaining: 343ms
# 13:	learn: 0.2249167	total: 55.1ms	remaining: 338ms
# 14:	learn: 0.2117506	total: 59ms	remaining: 334ms
# 15:	learn: 0.2005196	total: 62.8ms	remaining: 330ms
# 16:	learn: 0.1874608	total: 66.7ms	remaining: 326ms
# 17:	learn: 0.1773512	total: 70.6ms	remaining: 321ms
# 18:	learn: 0.1661820	total: 74.7ms	remaining: 318ms
# 19:	learn: 0.1566377	total: 78.5ms	remaining: 314ms
# 20:	learn: 0.1480319	total: 82.1ms	remaining: 309ms
# 21:	learn: 0.1396084	total: 86.1ms	remaining: 305ms
# 22:	learn: 0.1345896	total: 89.8ms	remaining: 301ms
# 23:	learn: 0.1271448	total: 93.5ms	remaining: 296ms
# 24:	learn: 0.1244315	total: 97.2ms	remaining: 292ms
# 25:	learn: 0.1216859	total: 101ms	remaining: 287ms
# 26:	learn: 0.1153455	total: 105ms	remaining: 283ms
# 27:	learn: 0.1108783	total: 108ms	remaining: 279ms
# 28:	learn: 0.1054087	total: 112ms	remaining: 275ms
# 29:	learn: 0.1016161	total: 116ms	remaining: 271ms
# 30:	learn: 0.0988538	total: 120ms	remaining: 267ms
# 31:	learn: 0.0951662	total: 125ms	remaining: 265ms
# 32:	learn: 0.0910176	total: 129ms	remaining: 263ms
# 33:	learn: 0.0869071	total: 133ms	remaining: 258ms
# 34:	learn: 0.0829814	total: 137ms	remaining: 254ms
# 35:	learn: 0.0793758	total: 140ms	remaining: 250ms
# 36:	learn: 0.0763899	total: 144ms	remaining: 245ms
# 37:	learn: 0.0726136	total: 148ms	remaining: 241ms
# 38:	learn: 0.0703382	total: 151ms	remaining: 237ms
# 39:	learn: 0.0673196	total: 155ms	remaining: 233ms
# 40:	learn: 0.0650423	total: 159ms	remaining: 228ms
# 41:	learn: 0.0632413	total: 162ms	remaining: 224ms
# 42:	learn: 0.0607381	total: 166ms	remaining: 220ms
# 43:	learn: 0.0586362	total: 170ms	remaining: 216ms
# 44:	learn: 0.0561230	total: 174ms	remaining: 213ms
# 45:	learn: 0.0546227	total: 178ms	remaining: 209ms
# 46:	learn: 0.0528757	total: 181ms	remaining: 205ms
# 47:	learn: 0.0508566	total: 185ms	remaining: 201ms
# 48:	learn: 0.0488491	total: 189ms	remaining: 197ms
# 49:	learn: 0.0472813	total: 193ms	remaining: 193ms
# 50:	learn: 0.0465799	total: 196ms	remaining: 189ms
# 51:	learn: 0.0453360	total: 200ms	remaining: 185ms
# 52:	learn: 0.0434383	total: 204ms	remaining: 181ms
# 53:	learn: 0.0419969	total: 207ms	remaining: 177ms
# 54:	learn: 0.0404342	total: 213ms	remaining: 174ms
# 55:	learn: 0.0391074	total: 217ms	remaining: 170ms
# 56:	learn: 0.0380181	total: 221ms	remaining: 166ms
# 57:	learn: 0.0368871	total: 224ms	remaining: 162ms
# 58:	learn: 0.0358755	total: 228ms	remaining: 158ms
# 59:	learn: 0.0345991	total: 232ms	remaining: 154ms
# 60:	learn: 0.0330107	total: 235ms	remaining: 150ms
# 61:	learn: 0.0323130	total: 239ms	remaining: 146ms
# 62:	learn: 0.0312862	total: 243ms	remaining: 143ms
# 63:	learn: 0.0302943	total: 246ms	remaining: 139ms
# 64:	learn: 0.0291220	total: 250ms	remaining: 135ms
# 65:	learn: 0.0283837	total: 254ms	remaining: 131ms
# 66:	learn: 0.0278404	total: 258ms	remaining: 127ms
# 67:	learn: 0.0271359	total: 261ms	remaining: 123ms
# 68:	learn: 0.0258609	total: 265ms	remaining: 119ms
# 69:	learn: 0.0249721	total: 269ms	remaining: 115ms
# 70:	learn: 0.0241134	total: 273ms	remaining: 111ms
# 71:	learn: 0.0233287	total: 277ms	remaining: 108ms
# 72:	learn: 0.0227106	total: 280ms	remaining: 104ms
# 73:	learn: 0.0223477	total: 284ms	remaining: 99.7ms
# 74:	learn: 0.0216711	total: 288ms	remaining: 95.9ms
# 75:	learn: 0.0209123	total: 291ms	remaining: 92ms
# 76:	learn: 0.0206044	total: 295ms	remaining: 88.1ms
# 77:	learn: 0.0201663	total: 298ms	remaining: 84.2ms
# 78:	learn: 0.0196392	total: 302ms	remaining: 80.3ms
# 79:	learn: 0.0188703	total: 306ms	remaining: 76.4ms
# 80:	learn: 0.0182687	total: 310ms	remaining: 72.6ms
# 81:	learn: 0.0177740	total: 313ms	remaining: 68.7ms
# 82:	learn: 0.0171861	total: 317ms	remaining: 64.9ms
# 83:	learn: 0.0168832	total: 320ms	remaining: 61ms
# 84:	learn: 0.0165404	total: 324ms	remaining: 57.2ms
# 85:	learn: 0.0162297	total: 328ms	remaining: 53.4ms
# 86:	learn: 0.0157757	total: 332ms	remaining: 49.5ms
# 87:	learn: 0.0154583	total: 335ms	remaining: 45.7ms
# 88:	learn: 0.0150969	total: 339ms	remaining: 41.9ms
# 89:	learn: 0.0147414	total: 343ms	remaining: 38.1ms
# 90:	learn: 0.0144812	total: 346ms	remaining: 34.3ms
# 91:	learn: 0.0141985	total: 350ms	remaining: 30.5ms
# 92:	learn: 0.0138342	total: 354ms	remaining: 26.6ms
# 93:	learn: 0.0136173	total: 358ms	remaining: 22.8ms
# 94:	learn: 0.0132528	total: 361ms	remaining: 19ms
# 95:	learn: 0.0129527	total: 365ms	remaining: 15.2ms
# 96:	learn: 0.0125848	total: 369ms	remaining: 11.4ms
# 97:	learn: 0.0124191	total: 373ms	remaining: 7.61ms
# 98:	learn: 0.0122227	total: 377ms	remaining: 3.8ms
# 99:	learn: 0.0119560	total: 380ms	remaining: 0us
#
# Stacking classifier training Accuracy: 1.00
# Stacking classifier test Accuracy: 0.94

# %%
#Evaluation Metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report

y_pred = stacking.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)


accuracy = accuracy_score(y_test, y_pred)
print("\nAccuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-Score:", f1)

roc_auc = roc_auc_score(y_test, stacking.predict_proba(X_test)[:, 1])
print("ROC-AUC:", roc_auc)

class_report = classification_report(y_test, y_pred)
print("\nClassification Report:")
print(class_report)
# Out:
# Confusion Matrix:
# [[124   4]
#  [  6  21]]
#
# Accuracy: 0.9354838709677419
# Precision: 0.84
# Recall: 0.7777777777777778
# F1-Score: 0.8076923076923077
# ROC-AUC: 0.9661458333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       128
#            1       0.84      0.78      0.81        27
#
#     accuracy                           0.94       155
#    macro avg       0.90      0.87      0.88       155
# weighted avg       0.93      0.94      0.93       155

# %% [markdown]
# Confusion Matrix:
# [[124   4]
#  [  6  21]]
#
# Accuracy: 0.9354838709677419
# Precision: 0.84
# Recall: 0.7777777777777778
# F1-Score: 0.8076923076923077
# ROC-AUC: 0.9661458333333333
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       128
#            1       0.84      0.78      0.81        27
#
#     accuracy                           0.94       155
#    macro avg       0.90      0.87      0.88       155
# weighted avg       0.93      0.94      0.93       155

# %%
#log loss calculation
from sklearn.metrics import log_loss

def balance_logloss(y_test, y_pred):
    logloss_positive = log_loss(y_test, y_pred)
    logloss_negative = log_loss(1 - y_test, 1-y_pred)
    balance_logloss = (logloss_positive + logloss_negative)/2.0
    
    return balance_logloss

balance_logloss(y_test, y_pred)
# Out:
# 2.325396992846268

# %% [markdown]
# ##### The best result of stacking is used for predicting the provided submit-test for the competition submission

# %%
test_preds = stacking.predict_proba(test1)
test_preds
# Out:
# array([[0.88194551, 0.11805449],
#        [0.88194551, 0.11805449],
#        [0.88194551, 0.11805449],
#        [0.88194551, 0.11805449],
#        [0.88194551, 0.11805449]])

# %%
submit = pd.DataFrame({'Id':df_test['Id'], 'class_0': test_preds[:, 0], 'class_1': test_preds[:, 1]})
submit
# Out:
#              Id   class_0   class_1
# 0  00eed32682bb  0.881946  0.118054
# 1  010ebe33f668  0.881946  0.118054
# 2  02fa521e1838  0.881946  0.118054
# 3  040e15f562a2  0.881946  0.118054
# 4  046e85c7cc7f  0.881946  0.118054

# %%
submit.to_csv('/kaggle/working/submission.csv', index=False)
submit=pd.read_csv("/kaggle/working/submission.csv")
submit.head()
# Out:
#              Id   class_0   class_1
# 0  00eed32682bb  0.881946  0.118054
# 1  010ebe33f668  0.881946  0.118054
# 2  02fa521e1838  0.881946  0.118054
# 3  040e15f562a2  0.881946  0.118054
# 4  046e85c7cc7f  0.881946  0.118054
